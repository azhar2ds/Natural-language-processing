# %% [markdown]
# # Analyzing Wikipedia Pages
#
# In this short data engineering focused project, we'll be working with data scraped from Wikipedia.

# %% [markdown]
# ## Introduction
# Wikipedia is maintained by volunteer content contributors and editors who continuously improve content. Wikipedia can be edited by anyone, and because it is crowdsourced, it's been able to rapidly assemble a huge library of articles.
#
# In this guided project, we'll be analyzing 54 megabytes worth of articles to figure out patterns in the Wikipedia writing and content presentation style. The articles were scraped by hitting random pages on Wikipedia, then downloading the contents using the requests package, which can be found here: http://docs.python-requests.org/en/master/. The scraping code is also in this folder that the project is in, in the scrape_random.py file.
#
# Articles were saved using the last component of their URLs. For example, a page on Wikipedia has the URL structure https://en.wikipedia.org/wiki/Yarkant_County. If we were saving the article with the previous URL, we'd save it to the file Yarkant_County.html. All the data files are stored in the wiki folder. Note that the files are raw HTML.
#
# Also note that the page is a fairly standard HTML page, and has embedded Javascript code. However, we'll be able to ignore the embedded Javascript during our analysis, so it should not be a problem.
#
# The main goals:
# * Extract only the text from the Wikipedia pages, and remove all HTML and Javascript markup.
# * Remove common page headers and footers from the Wikipedia pages.
# * Figure out what tags are the most common in Wikipedia pages.
# * Figure out patterns in the text.
#
# Let's get started by exploring a single data file.

# %%
# get some tools
import os

# list all files in wiki folder - it's a lot!
os.listdir("wiki")
# Out:
# ['Furubira_District,_Hokkaido.html',
#  'Valentin_Yanin.html',
#  'Kings_XI_Punjab_in_2014.html',
#  'William_Harvey_Lillard.html',
#  'Radial_Road_3.html',
#  'George_Weldrick.html',
#  'Zgornji_Otok.html',
#  'Blue_Heelers_(season_8).html',
#  'Taggen_Nunatak.html',
#  '1951_National_League_tie-breaker_series.html',
#  'List_of_number-one_singles_of_1993_(Finland).html',
#  'Vrila.html',
#  'William_Henry_Porter.html',
#  'Clive_Brown_(footballer).html',
#  '2010_Karshi_Challenger_%E2%80%93_Singles.html',
#  'Blick_nach_Rechts.html',
#  'Central_District_(Rezvanshahr_County).html',
#  'Gal%C3%A1pagos,_Guadalajara.html',
#  'Campus_of_Texas_A%26M_University.html',
#  'Alexios_Aspietes.html',
#  'Mei_Lanfang.html',
#  'Thalkirchen-Obersendling-Forstenried-F%C3%BCrstenried-Solln.html',
#  'Coalville_Town_railway_station.html',
#  'Gennady_Lesun.html',
#  'Bartrum_Glacier.html',
#  'Victor_S._Mamatey.html',
#  'Gottfried_Keller.html',
#  'Table_Point_Formation.html',
#  'Nobuhiko_Ushiba.html',
#  'Master_of_Space_and_Time.html',
#  'Early_medieval_states_in_Kazakhstan.html',
#  'Eressa_aperiens.html',
#  'Companys,_proc%C3%A9s_a_Catalunya.html',
#  'Myrtle_(sternwheeler).html',
#  'Abanycha_bicolor.html',
#  'Aubrey_Fair.html',
#  'Urban_chicken.html',
#  'Elgin_National_Watch_Company.html',
#  'Goran_Obradovi%C4%87_(footballer,_born_1976).html',
#  'Bluesin%27_Around.html',
#  'Pr%C3%A9liminaires.html',
#  'Antae_temple.html',
#  'Metis_Institute_of_Polytechnic.html',
#  '1953%E2%80%9354_FA_Cup_qualifying_rounds.html',
#  'Sverre_Solberg.html',
#  'John_Reid_(British_Army_officer).html',
#  'List_of_mountains_of_the_Falkland_Islands.html',
#  'Fischli.html',
#  'Aylon_Darwin_Tavella.html',
#  'Sambhaji_Raje_Chhatrapati.html',
#  'Alexander_Rizzoni.html',
#  'Pixley_Township,_Clay_County,_Illinois.html',
#  'Jules_Verne_ATV.html',
#  'Tomohiko_It%C5%8D_(director).html',
#  'Battle_of_Isonzo_(489).html',
#  'Pictogram.html',
#  'Alan_Oakley.html',
#  'Le_Premier_Sexe.html',
#  'Eugamandus_brunneus.html',
#  'Arthur_Norman.html',
#  'Feel_No_Fret.html',
#  'Claire_Danes.html',
#  'Adish_Aggarwala.html',
#  'Egg_coffee.html',
#  'Diplacus_aurantiacus.html',
#  'Sumba%E2%80%93Flores_languages.html',
#  'Justus_Ferdinand_Poggenburg_II.html',
#  'Svendborg_Skibsv%C3%A6rft.html',
#  'Communities_of_Tulu_Nadu.html',
#  'Supermoon.html',
#  'Ron_Harvey_(rugby_union).html',
#  'Olivaceous_flatbill.html',
#  'Javier_Bruses.html',
#  'Mitrella_guerreiroi.html',
#  'Louis_Vivet.html',
#  'Yarkant_County.html',
#  'Mrs._Wilkes%27_Dining_Room.html',
#  'Theonellamide_F.html',
#  'PTPRS.html',
#  'Legge.html',
#  'Constance_D%27Arcy_Mackay.html',
#  'Tom_Buffington.html',
#  'Leuke_Kome.html',
#  'Horace_Pinker.html',
#  'C%27est_la_vie_(Khaled_song).html',
#  'Kelvin_R._Throop.html',
#  'Yemeni_rial.html',
#  'Miss_Guatemala_2008.html',
#  'Merwin_Hodel.html',
#  'A_Beautiful_Valley.html',
#  'H._T._Hackney_Company.html',
#  'Berzeliustinden.html',
#  'John_Nelson_(merchant).html',
#  'Short_Message_service_center.html',
#  'Lebanon_at_the_1980_Winter_Olympics.html',
#  'Streatfeild_family.html',
#  'Kendal_Williams.html',
#  'List_of_women%27s_football_clubs_in_Japan.html',
#  'Tam%C3%A1s_Buday.html',
#  'Jeff_Weise.html',
#  'William_Harper_(South_Carolina).html',
#  '2007%E2%80%9308_Huddersfield_Town_A.F.C._season.html',
#  'Shanghai_Shuffle.html',
#  'Danny_Gray.html',
#  'Platinum_fulminate.html',
#  'Guyana_at_the_2010_Central_American_and_Caribbean_Games.html',
#  'Alpine_skiing_at_the_1994_Winter_Olympics_%E2%80%93_Men%27s_combined.html',
#  'Jeecy-Vea.html',
#  'The_Wire_(JTF-GTMO).html',
#  'Turowo,_Pomeranian_Voivodeship.html',
#  'Mike_Purdy.html',
#  'Hagen_Hauptbahnhof.html',
#  'Patrick_F._Philbin.html',
#  'Ribboned_sweetlips.html',
#  'Endre_Church.html',
#  'Nabil_Baha.html',
#  'Mudramothiram.html',
#  'Schlettau.html',
#  'Ameenapuram.html',
#  'Nathaniel_Merriman.html',
#  '2011_ITU_Duathlon_World_Championships.html',
#  'Mara_Keisling.html',
#  'Ragnar_Gustavsson.html',
#  'William_de_Pembroke.html',
#  'Teskey,_Kyrgyzstan.html',
#  'Mark_Maunder.html',
#  'Wheatland_High_School_(California).html',
#  'Markus_Blutsch.html',
#  'Kristiene_Gong.html',
#  'Punjab_War.html',
#  'Syncretocarpus.html',
#  'Gordon_Bau.html',
#  'Bibliography_of_Niue.html',
#  'Marv_Felderman.html',
#  'Code_page_1023.html',
#  'Discretionary_trust.html',
#  'Cryptographic_primitive.html',
#  'Alex_Kurtzman.html',
#  'William_Samuel_Viner.html',
#  'Nyck_de_Vries.html',
#  'Liga_de_F%C3%BAtbol_Profesional_Boliviano.html',
#  'Scott_McPherson.html',
#  'Kirsten_Klein.html',
#  '2011%E2%80%9312_Western_Collegiate_Hockey_Association_women%27s_ice_hockey_season.html',
#  'List_of_lakes_in_Independence_County,_Arkansas.html',
#  'David_Sands_(psychologist).html',
#  'Beyond_Magnetic.html',
#  'Church_of_the_SubGenius.html',
#  'Vaccinium_padifolium.html',
#  'ZNF644.html',
#  '2005%E2%80%9306_in_Welsh_football.html',
#  'Regina_Pacis_Catholic_Secondary_School.html',
#  'Filip_Pyrochta.html',
#  'Bal%C3%A1zs_Vill%C3%A1m.html',
#  'Gorgopis_subrimosa.html',
#  'Harry_Lynde_Bradley.html',
#  'North_Otago_Astronomical_Society_Observatory.html',
#  'Morgana_King.html',
#  'Don_Parsons_(ice_hockey).html',
#  'Evene.html',
#  'Therese_Maron.html',
#  'Plasnewydd.html',
#  'Belvedere,_London.html',
#  '1958_Wightman_Cup.html',
#  'Bias.html',
#  'Terry_Cox.html',
#  'Heo_Mok.html',
#  'Maple_Jam_Music_Group.html',
#  'Heiko_M%C3%A4rz.html',
#  'Imperial_Venus_(film).html',
#  'Charles_Stuart_(rugby_union).html',
#  'Yarumal.html',
#  'Olive_Dennis.html',
#  'Italy%E2%80%93United_States_relations.html',
#  'Camp_Nelson_Confederate_Cemetery.html',
#  'Treaty_of_Warsaw_(1970).html',
#  'Bill_Widenhouse.html',
#  'Benny_Lee.html',
#  '1898_Colgate_football_team.html',
#  'Caprinia_versicolor.html',
#  'P%C5%82az%C3%B3wka.html',
#  'MoneyHunt.html',
#  'Neville_Hewitt_(American_football).html',
#  'Faces_(Run%E2%80%93D.M.C._song).html',
#  'Dialogue_for_Hungary.html',
#  'Wu_Jin.html',
#  'Kul_Gul.html',
#  'Igor_and_Grichka_Bogdanoff.html',
#  'Tapat%C3%ADo_hot_sauce.html',
#  'Two_House_theology.html',
#  'Tramery.html',
#  'Revolutionary_Vol._1.html',
#  'Gaston_Lane.html',
#  'MobiasBanca.html',
#  'Lectionary_69.html',
#  'Arvind_Gokhale.html',
#  'Thomas_Croci.html',
#  'T%C5%8Dr%C5%8D_nagashi.html',
#  'Medicago_murex.html',
#  'Red-eyed_dove.html',
#  'Jazz_at_the_Plaza_Vol._II.html',
#  'Josef_Mik.html',
#  'AVM_GmbH.html',
#  '2001_Australian_Individual_Speedway_Championship.html',
#  'Mariana_Mazzucato.html',
#  'United_Nations_Security_Council_Resolution_731.html',
#  'Oldfield_Baby_Great_Lakes.html',
#  'Redwater,_Mississippi.html',
#  'Wangerooge-class_tug.html',
#  'Achaea_faber.html',
#  'Ramana,_Pakistan.html',
#  'Charles_Page_(cricketer).html',
#  'Sweeper.html',
#  'Canbelego_County.html',
#  'Wilson_Global_Explorer.html',
#  'Craig_Chester.html',
#  'Derek_Acorah.html',
#  'Wilbraham_%26_Monson_Academy.html',
#  'Mountune_Racing.html',
#  'AB_v_CD.html',
#  'Jack_Goes_Home.html',
#  '2016_Minnesota_Vikings_season.html',
#  'Morning_Glory_(2010_film).html',
#  'Flashmob_(album).html',
#  'I_Marine_Expeditionary_Force.html',
#  'KDDQ.html',
#  'Tim_Spencer_(singer).html',
#  'Suri,_Kerman.html',
#  'Seeking_Gaddafi.html',
#  'Jotedar.html',
#  'Kyokutou_I_Love_You.html',
#  'The_Portal_(community_center).html',
#  'John_C._Freeman_Weather_Museum.html',
#  'Curtiss-Wright_Hangar_(Columbia,_South_Carolina).html',
#  'S%C3%BCderelbe.html',
#  'Mick_Crotty.html',
#  'Juan_Carlos_Pinz%C3%B3n.html',
#  'Now_That%27s_What_I_Call_Music!_55_(U.S._series).html',
#  'Johnny_Morris_(American_football).html',
#  'Lower_Blackburn_Grade_Bridge.html',
#  'Van_Buren,_Ohio.html',
#  'Rules_of_Engagement_(Alexander_novel).html',
#  'The_Wedding_(Sparks_novel).html',
#  'West_Valley,_Washington.html',
#  '2017_Orange_County_Breakers_season.html',
#  'Fureai_kippu.html',
#  'Margo_Reuten.html',
#  'Saladino%27s_Inc.html',
#  'The_Master_Plan_(album).html',
#  'Mark_Baker_(basketball).html',
#  'Zehut.html',
#  'Sol_Eclipse.html',
#  'Para%C3%B1aque_National_High_School,_Don_Galo_Annex.html',
#  '2004_Tuvalu_A-Division.html',
#  'Jonathan_A._Goldstein.html',
#  'Naoise_%C3%93_Muir%C3%AD.html',
#  'F%C3%A9lix_C%C3%A1rdenas.html',
#  '83_(number).html',
#  'SBOA_School_%26_Junior_College.html',
#  'Devil_on_Horseback.html',
#  'Siuniu.html',
#  'Devarampally.html',
#  'SolydXK.html',
#  'Intel_QuickPath_Interconnect.html',
#  'Sierra_Leone_Studies.html',
#  'Harry_Hill_Bandholtz.html',
#  'Bijou,_California.html',
#  'Abdelwahid_Aboud_Mackaye.html',
#  'Equestrian_at_the_1936_Summer_Olympics.html',
#  'Pergamus.html',
#  'Biorock.html',
#  '2016%E2%80%9317_New_Zealand_Football_Championship.html',
#  'Antigonadotropin.html',
#  'Salem-Auburn_Streets_Historic_District.html',
#  'Henrique_da_Silveira.html',
#  'Jane_Wrightson.html',
#  'Gregory_Fortuin.html',
#  'Prisons_in_Bolivia.html',
#  'Ga%C5%A1parci.html',
#  'Paul_Maddrell.html',
#  'Vivian_Prokop.html',
#  'Oued_Tl%C3%A9lat.html',
#  'Paser_Crossword_Stela.html',
#  'Shpolskii_matrix.html',
#  'Bruce_Conte.html',
#  'Old_Mill_Creek,_Illinois.html',
#  'SC_Goldau.html',
#  'Robert_Frederick_Blum.html',
#  'Meydan-e_Jahad_Metro_Station.html',
#  'Sagrai.html',
#  'Falman-County_Acres,_Texas.html',
#  'Sa_Re_Ga_Ma_Pa_Challenge_USA_2008.html',
#  'La_Franja.html',
#  'Estadio_Municipal_Pozoblanco.html',
#  'Unionidae.html',
#  'Corporation_(university).html',
#  '1910_in_literature.html',
#  'Robert_Boehringer.html',
#  'Social_impact_of_YouTube.html',
#  'FC_Khikhani_Khulo.html',
#  'Cobble_Hill,_Brooklyn.html',
#  'The_Lavender_Cowboy.html',
#  'Coup_d%27%C3%A9tat.html',
#  'Tomislav_Erceg.html',
#  'USS_Parris_Island_(AG-72).html',
#  'Meir_Zlotowitz.html',
#  'Awali.html',
#  'Gacharageini.html',
#  'Fortuna_Glacier.html',
#  'Dragnet_(franchise).html',
#  'Winters-Wimberley_House.html',
#  'Ban_On.html',
#  '1915_Montana_football_team.html',
#  'Vijay_Govindarajan.html',
#  'Aiva.html',
#  '2011_Wainwright_Roaming_Buffalo_Classic.html',
#  'Uralochka_Zlatoust.html',
#  'Sybra_preapicemaculata.html',
#  'Papyrus_Oxyrhynchus_56.html',
#  'Promises,_Promises_(Incubus_song).html',
#  'Josh_West.html',
#  'Second_Valley,_South_Australia.html',
#  'Doug_Sahm_and_Band.html',
#  'Hope_7_(album).html',
#  'Mohamed_El-Sayed.html',
#  'Qalat_Kat.html',
#  'Woodward_Dream_Cruise.html',
#  'USS_Goldcrest.html',
#  '2016%E2%80%9317_Little_Rock_Trojans_women%27s_basketball_team.html',
#  'Aniavan.html',
#  'Instrumental.html',
#  'Christopher_Speer.html',
#  'Maniitsoq_structure.html',
#  'Minardi_M185.html',
#  'Millennium_Art_Academy.html',
#  'Australian_Musician_(magazine).html',
#  'Charlton_baronets.html',
#  'Cheddar_Ales.html',
#  'Dewoitine_D.21.html',
#  'List_of_Bellator_MMA_events.html',
#  'Tubular_Bells_II.html',
#  'Touch_FM_(Coventry).html',
#  'Kadamaha.html',
#  'James_L._Hull.html',
#  'Furto_di_sera_bel_colpo_si_spera.html',
#  'Hayes_Township,_Clay_County,_Kansas.html',
#  'Pontefract_by-election,_1941.html',
#  'Meleh_Kabud-e_Sofla.html',
#  'Symeon_Stylites_of_Lesbos.html',
#  'Kellie_Jones.html',
#  'Dominique_Voynet.html',
#  'Mohammad_Reza_Niknahal.html',
#  'Garden-based_learning.html',
#  'Sir_Run_Run_Shaw_Hospital.html',
#  'List_of_Argentine_Primera_Divisi%C3%B3n_transfers_January_2011.html',
#  'Gaetanus_Matthew_Perez.html',
#  'Sudanese_pound.html',
#  'Exploratorium_(film).html',
#  'Foulonia.html',
#  'Reb_Russell.html',
#  'Miltochrista_fuscozonata.html',
#  'Luvvie_Darling.html',
#  'Amborella.html',
#  'List_of_Bratz_episodes.html',
#  'Udi,_Enugu.html',
#  'Canyamars.html',
#  'Kenny_Cordray.html',
#  'Siege_of_Valenciennes_(1793).html',
#  'Santa_Mar%C3%ADa_Yaves%C3%ADa.html',
#  'Baddiewinkle.html',
#  'Chemin_d%27Aylmer.html',
#  'SSR-180,711.html',
#  'David_Solomona.html',
#  'Rally_for_Democracy_and_Progress_(Benin).html',
#  'I_Am_Cold.html',
#  'Sarah_Blakley-Cartwright.html',
#  'Rubber_Biscuit.html',
#  'Heald_Green.html',
#  'Charles_Smith_Wilcox.html',
#  'Swathi_Chinukulu.html',
#  'Noise_(song).html',
#  'Maukala.html',
#  'Hilyard_Robinson.html',
#  'Shellie_Morris.html',
#  'Bob_Bass.html',
#  'Diphilus_(physician).html',
#  'Arun_K._Pati.html',
#  'Agaritine_gamma-glutamyltransferase.html',
#  'Sky_Regional_Airlines.html',
#  'Wilhelm_August_Graah.html',
#  'Avenira.html',
#  'Slade_School_of_Fine_Art.html',
#  'Zane_Radcliffe.html',
#  'Devitt_Insurance.html',
#  'Lincoln_Clarkes.html',
#  'Panhandle%E2%80%93Plains_Historical_Museum.html',
#  'Bahmanabad-e_Olya.html',
#  'Tarsila_do_Amaral.html',
#  'Ioana_Badea.html',
#  'The_Gentleman_Without_a_Residence_(1915_film).html',
#  'Troso_da_Monza.html',
#  'Walter_of_Durham.html',
#  'James_Wilkes_Maurice.html',
#  'Section_20_of_the_Canadian_Charter_of_Rights_and_Freedoms.html',
#  'Ferdinand_Mainzer.html',
#  'Keeled_sideband.html',
#  'Palio_zosterae.html',
#  'Lydia_Villa-Komaroff.html',
#  'Henri_Braqueni%C3%A9.html',
#  'Nickel(II)_hydroxide.html',
#  'Usher_Gahagan.html',
#  'John_V._G._Posey_House.html',
#  'Kfarhata.html',
#  'James_Alexander_Ulio.html',
#  'De_La_Salle_University_%E2%80%93_Dasmari%C3%B1as.html',
#  'When_You_Loved_Me.html',
#  'Flat_roof.html',
#  'Jack_Wong.html',
#  'The_Love-Girl_and_the_Innocent.html',
#  'Manhattan_Murder_Mystery.html',
#  'DiGiorgio_Corporation.html',
#  'Eugenio_Morelli.html',
#  'Kenneth_Thomas_(cricketer).html',
#  'Mar%C3%ADa_Calder%C3%B3n.html',
#  'James_Magee.html',
#  'Bill_Price_(baseball).html',
#  'Mount_Jim_Crow_National_Park.html',
#  'Avengers_Academy.html',
#  'Scrobipalpa_halophila.html',
#  'Swan_neck_deformity.html',
#  'Chhatrasal.html',
#  'Raymond_II,_Count_of_Toulouse.html',
#  'Macroglossum_pseudoluteata.html',
#  'Antibiotic_use_in_livestock.html',
#  'Omaha_Racers.html',
#  'Syngenor.html',
#  'Mecklenburg_Switzerland_and_Lake_Kummerow_Nature_Park.html',
#  'List_of_largest_chemical_producers.html',
#  'X-Cops_(band).html',
#  'Hannover_Indians.html',
#  'Carlos_Martins_(musician).html',
#  'Women%27s_javelin_throw_world_record_progression.html',
#  'Asparuh_Peak.html',
#  'Robert_K._Zukowski.html',
#  'Gorfion.html',
#  'Marson.html',
#  'I%27ve_Heard_That_Song_Before.html',
#  'Jens_Pauli_Skaalum.html',
#  'Chestnut_pie.html',
#  'Vitaly_Bianki.html',
#  'Coronium_(gastropod).html',
#  'Arnold_Freiherr_von_Biegeleben.html',
#  'Acacia_dermatophylla.html',
#  'Lis_L%C3%B8wert.html',
#  'Typhoon_Hester_(1952).html',
#  'Ugo_Okoye.html',
#  '2014%E2%80%9315_Kansas_State_Wildcats_men%27s_basketball_team.html',
#  'Kokan_Colony.html',
#  'Oleg_Novitskiy.html',
#  'Llwyn-Cus.html',
#  'Wilhelm_Wagenfeld_House.html',
#  'Erigeron_canaani.html',
#  'Eternamente_Romanticos.html',
#  'Lecithocera_sextacta.html',
#  'Arthur_Lelyveld.html',
#  'Bonny_River.html',
#  'Charles_Sears.html',
#  'Ingrid_Guimar%C3%A3es.html',
#  'Jonas_Ar%C4%8Dikauskas.html',
#  'Tonga_national_basketball_team.html',
#  'City_of_Mandaluyong_Science_High_School.html',
#  'Oktyabrsky_District,_Russia.html',
#  'Archibald_Gordon_(British_Army_officer).html',
#  'Kusaka_Station.html',
#  'Plze%C5%88_Zoo.html',
#  'WLSR.html',
#  'Friendship,_Wake_County,_North_Carolina.html',
#  'Wolfgang_Lutz.html',
#  'Curridge.html',
#  'Kendalia,_Texas.html',
#  'Celebrity_doll.html',
#  'Venezuelan_referendum,_1957.html',
#  'Australian_hardcore.html',
#  'Lake_County_Examiner.html',
#  'HMS_Robust.html',
#  '985_Innovative_Platforms_for_Key_Disciplines_Project.html',
#  'Hermann_Nuding.html',
#  'Love,_Sax_and_Flashbacks.html',
#  'Kolound.html',
#  'Ordinary,_Virginia.html',
#  'Kanakomyrtus.html',
#  'Bulbophyllum_biflorum.html',
#  'Copamyntis_infusella.html',
#  'Archiepiscopal_Palace,_Rouen.html',
#  'Charged_Records.html',
#  'Cosmopterix_similis.html',
#  'Jyoti_Raju.html',
#  'Apocephalus_borealis.html',
#  'Bernard-Augustin_Conroy.html',
#  'Ready_or_Not_(Young_JV_album).html',
#  'Indhiya_Jananayaga_Katchi.html',
#  'St._Peter%27s_Church,_Tiberias.html',
#  'Parkgate_railway_station.html',
#  'C11orf30.html',
#  'Mr_Freedom_(fashion).html',
#  'Stade_Municipal_de_Djougou.html',
#  'Suwannee_River_Junior_College.html',
#  'Estelle_v._Smith.html',
#  'Arabic_Toilers%27_Movement.html',
#  'Koevtsi,_Gabrovo_Province.html',
#  'Kentucky_Auditor_election,_2011.html',
#  '2013_FIA_WTCC_Race_of_Russia.html',
#  'Taipa_Houses%E2%80%93Museum.html',
#  'Tobi_trousers.html',
#  'Museum_of_John_Paul_II_Collection.html',
#  'Gbiri-Niragu_language.html',
#  'Virajpet_(Vidhan_Sabha_constituency).html',
#  'List_of_people_from_Bangor,_Maine.html',
#  'One_Night_of_Sin.html',
#  'Cabrini%E2%80%93Green,_Chicago.html',
#  'Ek_Dil_Sau_Afsane.html',
#  'Pustiu_River.html',
#  'Majeepura.html',
#  'Tongyi,_Mingin.html',
#  'Zeiraphera.html',
#  'Benidorm_Bastards.html',
#  'Burmese_shrike.html',
#  'Axel_Revold.html',
#  '2009_World_Junior_Ice_Hockey_Championships_rosters.html',
#  'Qatar_at_the_2013_World_Championships_in_Athletics.html',
#  'Nepal_at_the_2008_Summer_Paralympics.html',
#  'Daniel_Cerone.html',
#  'Alan_Sheehan.html',
#  'Work_domain_analysis.html',
#  'Pochyta.html',
#  'Jarom%C3%ADr_%C5%A0imr.html',
#  'Simon%27s_Town_railway_station.html',
#  'Larvicide.html',
#  'Power_transfer_unit.html',
#  'Crab-eating_frog.html',
#  'Percy_William_Bunting.html',
#  'Meanings_of_minor_planet_names:_440,001%E2%80%93450,000.html',
#  'Chief_Justice_of_New_Zealand.html',
#  'KUMT.html',
#  'Vanavara_Airport.html',
#  'Lord_Howe%27s_action,_or_the_Glorious_First_of_June.html',
#  '55th_parallel_south.html',
#  'Aleksandra_Jagie%C5%82o.html',
#  'Curtis_Whitley.html',
#  'Post_(structural).html',
#  'Lake_Lagunitas.html',
#  'Failing_Office_Building.html',
#  'Carley_State_Park.html',
#  'Puerto_Rico_at_the_2013_World_Aquatics_Championships.html',
#  'Eyes_Galaxies.html',
#  'Kistenuten.html',
#  'Children_of_the_Grave.html',
#  'Bagrat_VI_of_Georgia.html',
#  'Pushkar.html',
#  'List_of_Uzbek_films_of_2014.html',
#  'Konstantin_%22Samokovetsa%22_Dimitrov.html',
#  'Cygany,_Masovian_Voivodeship.html',
#  'KMTZ.html',
#  'Football_Foundation.html',
#  'Ministry_of_Development_Planning_and_Statistics.html',
#  'Caney_Creek_(Matagorda_Bay).html',
#  'Solanum_chilliasense.html',
#  'Ballard_Memorial_High_School.html',
#  'Thanks_Again.html',
#  'Dowell_Philip_O%27Reilly.html',
#  'The_Land_of_the_Dead.html',
#  'Yoshinkan.html',
#  'John_Maitland_(Royal_Navy_officer).html',
#  'Social_dualism.html',
#  'Golabkhvaran.html',
#  'Liebig_Peak.html',
#  'Garrett_Lucash.html',
#  'Medical_Unit,_Self-contained,_Transportable.html',
#  '1st_Strategic_Aerospace_Division.html',
#  'Agnolin.html',
#  'Wren,_Alabama.html',
#  'Roselawn,_Indiana.html',
#  'Brograve_Mill.html',
#  'Ashley,_Wisconsin.html',
#  'Blue_SWAT.html',
#  'HMS_Stratagem_(P234).html',
#  'Poor_Richard%27s_Almanack_(TV_series).html',
#  'Pedro_Checa.html',
#  'Martha_Herbert.html',
#  'Goodnight%E2%80%93Loving_Trail.html',
#  'Adolf_Schulte.html',
#  'Danish_Maritime_Safety_Administration.html',
#  'Kiev_Missal.html',
#  'Don_Raye.html',
#  'Precorrin-6A_reductase.html',
#  'Strawberry_foliar_nematode.html',
#  'St._Paul_University_Iloilo.html',
#  'Roger_Brooke.html',
#  'Doumanaba.html',
#  'H._Larue_Renfroe.html',
#  'Giants%27_grave_of_S%27Ena%27e_Thomes.html',
#  'Crepidula_atrasolea.html',
#  'Sahanpur.html',
#  'Ksar_Nalut.html',
#  'Phong_Th%E1%BA%A1nh_%C4%90%C3%B4ng_A.html',
#  'Martinus_Hamconius.html',
#  'Sanford_Wallace.html',
#  'Gratitud.html',
#  'Al-Midan.html',
#  'Iwaki-Ishikawa_Station.html',
#  'Abraham_Stanyan.html',
#  'U.S._Snowboarding_Race_to_the_Cup.html',
#  'Seminemacheilus.html',
#  'British_Academy_Television_Award_for_Best_Comedy_(Programme_or_Series).html',
#  'FC_Bobruisk.html',
#  '2011_UK_Open_Qualifier_4.html',
#  'Monarch_Mountain.html',
#  'Johnny_B._Moore.html',
#  'Ayish_Bayou.html',
#  'Newton_Stone.html',
#  'Treaty_of_Ryswick.html',
#  'Kenneth_van_Kempen.html',
#  'Progressive_refinement.html',
#  'Zoom_Systems.html',
#  'Panchamrutham.html',
#  'Hoghiz.html',
#  'Peltigera_membranacea.html',
#  'Bazemore,_Alabama.html',
#  'Ovum_Recordings.html',
#  'Dick_Johnson_(clarinetist).html',
#  'Urodilatin.html',
#  'Stephen_Unwin_(director).html',
#  'Columbia_Airport_(Ohio).html',
#  'Shibanov.html',
#  'DWTE-TV.html',
#  'Bifidocarpus.html',
#  'Priscus_of_Epirus.html',
#  'Bibiana_Beglau.html',
#  'Ordinary_singularity.html',
#  'Castle_of_Cardona.html',
#  'Emmanuel_Muhammad.html',
#  'Bulbonaricus.html',
#  'Kelvin_Mbilinyi.html',
#  'Emily_(1964_song).html',
#  'Ricard_Card%C3%BAs.html',
#  'Greg_Halsey-Brandt.html',
#  'Kim_Yong-hwa.html',
#  'Queensland_Music_Festival.html',
#  'Clay_Township,_Clark_County,_Missouri.html',
#  'Liberty_Central_School_District.html',
#  'Kamakshyanagar.html',
#  'S%C3%A3o_Sebasti%C3%A3o_do_Alto.html',
#  'Kattukukke.html',
#  'Tischofer_Cave.html',
#  'Rob_Jones_(footballer,_born_1971).html',
#  'Embraer_Unidade_Gavi%C3%A3o_Peixoto_Airport.html',
#  'Barren_vegetation.html',
#  'Burbridge_Creek.html',
#  'Bye!_My_Boy!.html',
#  'Phil_Spence.html',
#  'Ronald_McCaffer.html',
#  'Macy_conferences.html',
#  'Belgium_women%27s_national_field_hockey_team.html',
#  'Dalian_Road_Station.html',
#  'Antonio_de_Zayas_(bishop).html',
#  'Oldham_Metropolitan_Borough_Council_election,_2000.html',
#  'Hideki_Kase.html',
#  'Acceptance_(Heroes).html',
#  'Enamul_Haque_(cricketer,_born_1966).html',
#  'RF_microwave_CAE_CAD.html',
#  'Ego_Dominus_Tuus.html',
#  'High_Efficiency_Image_File_Format.html',
#  'New_York_Women_Composers,_Inc..html',
#  'Newfoundland_general_election,_1848.html',
#  'Lungujja.html',
#  'Smeaton,_East_Lothian.html',
#  'Government_Polytechnic_Nagriya_Mod_Etah.html',
#  'Ma_Sen.html',
#  'Phenacobius_catostomus.html',
#  'Norderbrarup.html',
#  'Octomeria_lithophila.html',
#  'Joint_Committee_for_Traceability_in_Laboratory_Medicine.html',
#  'Yuga_(film).html',
#  'Clay_Research_Award.html',
#  'Kreslyuvtsi.html',
#  '33rd_New_Jersey_Volunteer_Infantry.html',
#  'Steinkjersannan.html',
#  'Carthage,_Cincinnati.html',
#  'Senapati_district.html',
#  'Frost_Township,_Michigan.html',
#  'Bay_of_Concepci%C3%B3n.html',
#  'Chhaparband_(Muslim).html',
#  'Guaricana_National_Park.html',
#  'Challenger_Banque_Nationale_de_Drummondville.html',
#  'Appa_(film).html',
#  'Ben_H._Williams.html',
#  'Hypocysta_angustata.html',
#  'Copenhagen_Skatepark.html',
#  'Saratoga_Automobile_Museum.html',
#  'Madhuri_Desai.html',
#  'Athletics_at_the_1994_Commonwealth_Games_%E2%80%93_Men%27s_pole_vault.html',
#  'Odder.html',
#  'Aldona_Orman.html',
#  'Vancouver_Furious_George.html',
#  'Havnar_R%C3%B3%C3%B0rarfelag.html',
#  'Dextran_1.html',
#  'HD_90156.html',
#  'WFGI-FM.html',
#  'Oculo-respiratory_syndrome.html',
#  'Zhongxing_Guesthouse.html',
#  '1988_State_of_Origin_series.html',
#  'Hemiargyropsis_frontalis.html',
#  'The_Audacity_to_Podcast.html',
#  'List_of_Polish_consorts.html',
#  'Third_Saturday_in_October.html',
#  'Antipater_of_Thessalonica.html',
#  'Santa_Maria_Imbaro.html',
#  'Brownfield_(software_development).html',
#  'George_Joseph_Trapp.html',
#  'Russell_Road_(Ontario).html',
#  'Maneswar_Brahma.html',
#  'Robin_Brooke.html',
#  '100_Greatest_Romanians.html',
#  'Cristian_Berdeja.html',
#  'King_Parker_House.html',
#  'Al-Nurayn_Mosque.html',
#  'John_Shaw_Rennie.html',
#  'Sobolewo,_Wysokie_Mazowieckie_County.html',
#  'Meneng_Constituency.html',
#  'List_of_Spaghetti_Western_films.html',
#  'Paul_Kenny_(politician).html',
#  'Luca_Luciano.html',
#  'Cannabis_in_Spain.html',
#  'VSX2.html',
#  'Varsity_College.html',
#  'Fahy,_County_Mayo.html',
#  'Keegan_Pereira_(footballer).html',
#  'Eudonia_notozeucta.html',
#  'Pirama.html',
#  'Shinpei_Matsushita.html',
#  'Boardman_Township,_Mahoning_County,_Ohio.html',
#  'Anton_von_Troeltsch.html',
#  'Vang_stone.html',
#  'Heinz_Inniger.html',
#  'Marion_Rockefeller_Weber.html',
#  'Abdulla_Majid_Al_Naimi.html',
#  'The_Future_(film).html',
#  'Fusinus_carvalhoriosi.html',
#  'List_of_Nymphaeales_of_Montana.html',
#  'Weiser_River.html',
#  'Elzear_Torreggiani.html',
#  'Scarlet_wrasse.html',
#  'Svinjare.html',
#  'G.O.Y.A._(Gunz_Or_Yay_Available).html',
#  'Switzerland_at_the_1992_Winter_Olympics.html',
#  'Chef_Wan.html',
#  'Viva_Villa!.html',
#  'Jon_Mullich.html',
#  'Clear_Creek_Township,_Cooper_County,_Missouri.html',
#  'A_Sport_and_a_Pastime.html',
#  'The_Right_Kinda_Lover.html',
#  'Plains,_Kansas.html',
#  'Baadj.html',
#  'George_Ellicott.html',
#  'Cortile_del_Belvedere.html',
#  'Mick_Kelly_(Australian_footballer).html',
#  'Somarasampettai.html',
#  'David_Jesson.html',
#  '%C5%8Cnog%C5%8D_Station.html',
#  'Nuno_Leal_Maia.html',
#  'Battle_of_Wattignies.html',
#  'Saravan,_Gilan.html',
#  'Colchester_Village_Historic_District.html',
#  'Watsonville_Junction,_California.html',
#  'Hayateumi_Hidehito.html',
#  'Oliver_Twist_(1912_American_film).html',
#  'Omar_Onsi.html',
#  'Utiel-Requena.html',
#  'Volume_One_(The_West_Coast_Pop_Art_Experimental_Band_album).html',
#  'Pozna%C5%84_Wola_railway_station.html',
#  'ISMACryp.html',
#  'Mirisah.html',
#  'USS_Impeccable_(AM-320).html',
#  'Bengt_Forsberg.html',
#  'Irihirose_Station.html',
#  'A_Month_of_Sundays_(miniseries).html',
#  'Teiji_Ito.html',
#  'Robert_E._Lee_(FCC).html',
#  'Giardini_Margherita.html',
#  'Upper_Beaches.html',
#  'Minister_of_Foreign_Affairs_(Egypt).html',
#  'Italian_submarine_Comandante_Fa%C3%A0_di_Bruno.html',
#  'Christine_Gardner.html',
#  'Durham_Women%27s_F.C..html',
#  'USS_Rose_Mary_(SP-1216).html',
#  'Shoreyjeh-ye_Do.html',
#  '%C3%89cole_des_Mines_de_Douai.html',
#  'Luciano_Mercante.html',
#  'Jeff_Boyd.html',
#  'Abbeville_Sluggers.html',
#  'East_Down_(Northern_Ireland_Parliament_constituency).html',
#  'Russian_Cultural_Centre_(Lviv).html',
#  'Morten_Rutkj%C3%A6r.html',
#  'Du%C5%A1anovo.html',
#  'Bowie_Race_Track.html',
#  'Gemma_Doyle_(politician).html',
#  'Thornton-le-Beans.html',
#  'Tommy_Hunter_(baseball).html',
#  'S%C3%B8rli.html',
#  'Frithjof_Schmidt.html',
#  'ARA_Garibaldi.html',
#  'How_Can_We_Hang_On_to_a_Dream%3F.html',
#  'Schwobsheim.html',
#  'Arrondissements_of_the_Yvelines_department.html',
#  'L._Fry.html',
#  'Hepatitis_B_virus.html',
#  'Jordan_Steel.html',
#  'Central_Luzon.html',
#  'Jack_Graham_(pastor).html',
#  'Sentences_(composition).html',
#  'Tropical_sprue.html',
#  'Elisa_von_der_Recke.html',
#  'Neurotica.html',
#  'Roxbury_Presbyterian_Church.html',
#  'Moosavi_Peace_Formula.html',
#  'Acrolophus_simulatus.html',
#  'Dennis_Chapman.html',
#  'Uruguayan_constitutional_referendum,_2014.html',
#  'Peter_Collingwood.html',
#  'List_of_molecular_graphics_systems.html',
#  'MOUSE_DHI.html',
#  'Hexachaeta_colombiana.html',
#  'Sot%C4%81panna.html',
#  '2015%E2%80%9316_Washington_Huskies_men%27s_basketball_team.html',
#  'Oligocentris_deciusalis.html',
#  '2008_Fed_Cup_World_Group_II.html',
#  'Camp_Liberty_killings.html',
#  'Hemet_Public_Library.html',
#  'Lin_Chia-yu.html',
#  'Omiodes_iridias.html',
#  'Shigeo_Kurata.html',
#  'Arthur_L._Aidala.html',
#  'Clocking_Out_Is_for_Suckers.html',
#  'List_of_gold_medalists_at_2006_South_Asian_Games.html',
#  'Gew%C3%A4chshaus_f%C3%BCr_tropische_Nutzpflanzen.html',
#  'The_Purpose_Driven_Church.html',
#  'Brendan_Foster.html',
#  'I%27m_Walking_Behind_You.html',
#  'Glinka_(crater).html',
#  'Larry_Brooks.html',
#  'Socket_423.html',
#  'Double_Wing_Attack.html',
#  'Arkansas_Highway_178.html',
#  'Taylour_Paige.html',
#  'Fraser_Lake_Airport.html',
#  'Potheri_village,_Kanchipuram.html',
#  'Pedro_Machuca.html',
#  'Roll%27s_partridge.html',
#  'Nejat_Alp.html',
#  'Checkerspot_(magazine).html',
#  'Functoid.html',
#  'Manitoba_general_election,_1896.html',
#  'Roman_Catholic_Diocese_of_Cervia.html',
#  'Lopez_v._Davis.html',
#  'Coenaculum_secundum.html',
#  'Football_at_the_National_Games_of_China.html',
#  'Vojin_%C4%86etkovi%C4%87.html',
#  'Sibling_Revelry.html',
#  'Isaac_Gr%C3%BCnewald.html',
#  'Waldoboro_(CDP),_Maine.html',
#  'Cecyl%C3%B3wka-Brz%C3%B3zka.html',
#  'List_of_birds_of_Malta.html',
#  '2009_English_cricket_season.html',
#  'Banovina_of_Croatia.html',
#  'Dakar_2:_The_World%27s_Ultimate_Rally.html',
#  'Anthony_Marten.html',
#  'Arcadio_Gonz%C3%A1lez.html',
#  'Boogie_Bunnies.html',
#  'Roque_P%C3%A9rez_Partido.html',
#  'Andrei_Gamalyan.html',
#  'Mykines,_Greece.html',
#  'Dresden-Plauen_railway_station.html',
#  'Kailas_Pal.html',
#  'Bad_Luck_(Social_Distortion_song).html',
#  'I,_Q_(book_series).html',
#  'Julien_Boisselier.html',
#  'Turkish_Men%27s_Volleyball_Championship.html',
#  'Joint_Social_Welfare_Institute.html',
#  'The_Summer_King.html',
#  'Burnin%27_Sneakers.html',
#  'Chapel_of_Mercy,_Monaco-Ville.html',
#  'Jazz_in_Turkey.html',
#  'Burnley_Borough_Council_election,_2011.html',
#  'National_Register_of_Historic_Places_listings_in_Allen_Parish,_Louisiana.html',
#  'Luiz_Henrique_Santos.html',
#  'Yasid.html',
#  '2001_NCAA_Division_I_Field_Hockey_Championship.html',
#  'Ctenodes_zonata.html',
#  'EDP_Sarichioi_Wind_Farm.html',
#  'Carte_Imagine%27R.html',
#  'Holly_Golightly_(comics).html',
#  'Johann_Christoph_Hoffbauer.html',
#  'Matthew_Liptak.html',
#  'Programa_Mejorando_tu_Autoestima.html',
#  'Philaeus.html',
#  'Kate_Harwood.html',
#  'Baltic_Peak.html',
#  'Westchester,_Los_Angeles.html',
#  'Laredo_Colombia_Solidarity_Port_of_Entry.html',
#  '104th_Logistic_Support_Brigade_(United_Kingdom).html',
#  'Pichoy_Airfield.html',
#  'Wreck_Island_Natural_Area_Preserve.html',
#  'Desmiphora_bijuba.html',
#  'Webb_Dock_railway_line.html',
#  'Helena_Nyblom.html',
#  'Hall_of_Mental_Cultivation.html',
#  'John_Whewell.html',
#  '2014%E2%80%9315_Albanian_Third_Division.html',
#  'Gulliver_Mickey.html',
#  'Henry_Horace_Williams.html',
#  'Hebden_Bridge_Picture_House.html',
#  'Marie-Jos%C3%A8phe_Jude.html',
#  'Circus_Avenue.html',
#  'Kettu_Kalyanam.html',
#  'Union_United_Church.html',
#  'Bill_Overstreet.html',
#  'Urs_Burkart.html',
#  'The_K_of_D.html',
#  'Gandigwad.html',
#  'Kentucky_Theater.html',
#  'USS_General_Putnam_(1857).html',
#  'George_Jones_(bishop).html',
#  'United_Nations_Security_Council_Resolution_1923.html',
#  'The_Hackensaw_Boys.html',
#  'Harry_Sacksioni.html',
#  'David_Beasley.html',
#  'Piracy_on_Falcon_Lake.html',
#  'Mammoth_Unified_School_District.html',
#  'Eggerberg_railway_station.html',
#  'Tillandsia_intermedia.html',
#  'Town_Yetholm.html',
#  'S%27portable_Scoreboards.html',
#  'Sparganothis_saracana.html',
#  'Smilax_laurifolia.html',
#  'Taylor_Williamson.html',
#  'Epropetes_metallica.html',
#  'Melanolagus_bericoides.html',
#  'BBCH-scale_(rice).html',
#  'La_Roca_de_la_Sierra.html',
#  'Russian_Party_in_Estonia.html',
#  'Henry_Louis_Larsen.html',
#  'Torovirinae.html',
#  'Moses_Hardy.html',
#  '1896_Indiana_Hoosiers_football_team.html',
#  'Els_Dottermans.html',
#  'Epichorista.html',
#  'Ownership_of_Rangers_F.C..html',
#  'Clinton_Engineer_Works.html',
#  'It%27s_Just_My_Funny_Way_of_Laughin%27.html',
#  'The_Showdown_Effect.html',
#  'My_Life_(Billy_Joel_song).html',
#  'Ramo_Stott.html',
#  'Geomancer_(comics).html',
#  'Enrique_Morales.html',
#  'Linowiec,_Kuyavian-Pomeranian_Voivodeship.html',
#  'Triptolemus_Evrychou.html',
#  'Claudia_Neidig.html',
#  'Keshav_Ginde.html',
#  'Cyclohexane_conformation.html',
#  'Dean_Kukan.html',
#  'List_of_Carboniferous_tetrapods.html',
#  'Sol_Orwell.html',
#  'Lucius_Allen_(politician).html',
#  'Elio_Calderini.html',
#  'Demographics_of_American_Samoa.html',
#  'Middle_Park,_Victoria.html',
#  'Peringiella_denticulata.html',
#  'Y%C3%AAn_B%C3%A1i.html',
#  'Young_Finnish_Party.html',
#  'Rudy:_The_Rudy_Giuliani_Story.html',
#  'Dysgonia_pudica.html',
#  'Klaus_Gerwien.html',
#  'Lee_Henderson_Watkins.html',
#  '%C3%89taule.html',
#  'Sabari.html',
#  'Timothy_Wanyonyi_Wetangula.html',
#  'Ivo_Siromahov.html',
#  'John_Jephson.html',
#  'Land_%26_Water_Australia.html',
#  'Shabbir_Kumar.html',
#  'Sylvia_Moss.html',
#  'West_Park_Bridge.html',
#  'Imperial_amazon.html',
#  '16th_Virginia_Infantry.html',
#  'North_Coast_(RTA_Rapid_Transit_station).html',
#  'Alex_McEachern.html',
#  'Kate_Quarrie.html',
#  'Cyclone_Gamede.html',
#  'William_McDonald_(Australian_politician).html']

# %%
# that was how many files...
len(os.listdir("wiki"))

# read one of them 
with open("wiki/Tommy_Hunter_(baseball).html") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Tommy Hunter (baseball) - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Tommy_Hunter_(baseball)","wgTitle":"Tommy Hunter (baseball)","wgCurRevisionId":768192910,"wgRevisionId":768192910,"wgArticleId":18744949,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from February 2016","1986 births","Living people","Sportspeople from Indianapolis","Baseball players from Indiana","Major League Baseball pitchers","Texas Rangers players","Baltimore Orioles players","Chicago Cubs players","Cleveland Indians players","Alabama Crimson Tide baseball players","Spokane Indians players","Bakersfield Blaze players","Frisco RoughRiders players","Oklahoma RedHawks players","Oklahoma City RedHawks players","Round Rock Express players","Bowie Baysox players","Norfolk Tides players","Delmarva Shorebirds players","Columbus Clippers players"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Tommy_Hunter_(baseball)","wgRelevantArticleId":18744949,"wgRequestId":"WLf0IApAMFoAAJ5HA8IAAABV","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q861479","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.13"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Tommy_Hunter_on_August_10%2C_2011.jpg/1200px-Tommy_Hunter_on_August_10%2C_2011.jpg"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Tommy_Hunter_(baseball)"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Tommy_Hunter_(baseball)"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Tommy_Hunter_baseball rootpage-Tommy_Hunter_baseball skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Tommy Hunter (baseball)</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><table class="infobox bordered vcard" style="width:22em">
# <tr>
# <th colspan="2" class="fn" style="text-align:center;font-size:125%;font-weight:bold;font-size:larger; background-color:#092C5C;color:#FFFFFF;"><span class="note">Tommy Hunter</span></th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center"><a href="/wiki/File:Tommy_Hunter_on_August_10,_2011.jpg" class="image"><img alt="Tommy Hunter on August 10, 2011.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Tommy_Hunter_on_August_10%2C_2011.jpg/220px-Tommy_Hunter_on_August_10%2C_2011.jpg" width="220" height="356" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Tommy_Hunter_on_August_10%2C_2011.jpg/330px-Tommy_Hunter_on_August_10%2C_2011.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Tommy_Hunter_on_August_10%2C_2011.jpg/440px-Tommy_Hunter_on_August_10%2C_2011.jpg 2x" data-file-width="1315" data-file-height="2127" /></a>
# <div>Hunter with the Baltimore Orioles</div>
# </td>
# </tr>
# <tr style="background-color:#8FBCE6;color:#092C5C;">
# <th colspan="2" style="text-align:center"><span class="note" style="font-weight:bold">Tampa Bay Rays – No. 49</span></th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center"><b><a href="/wiki/Relief_pitcher" title="Relief pitcher">Relief pitcher</a></b></td>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center"><b>Born:</b> <span style="display:none">(<span class="bday">1986-07-03</span>)</span> July 3, 1986 <span class="noprint ForceAgeToShow">(age&#160;30)</span><br />
# <a href="/wiki/Indianapolis" title="Indianapolis">Indianapolis</a>, <a href="/wiki/Indiana" title="Indiana">Indiana</a></td>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center">
# <table style="width:100%; border:none;border-collapse:collapse;">
# <tr>
# <td style="text-align:center;width:50%; border-width:0 1px 0 0;"><b>Bats:</b> Right</td>
# <td style="text-align:center;width:50%; border-width:0 0 0 1px;"><b>Throws:</b> Right</td>
# </tr>
# </table>
# </td>
# </tr>
# <tr style="background-color:#092C5C;color:#FFFFFF;">
# <th colspan="2" style="text-align:center">MLB debut</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center">August 1,&#160;2008,&#160;for the&#160;Texas Rangers</td>
# </tr>
# <tr style="background-color:#8FBCE6;color:#092C5C;">
# <th colspan="2" style="text-align:center">MLB statistics<br />
# <small>(through 2016 season)</small></th>
# </tr>
# <tr>
# <th scope="row" style="text-align:right; width:50%; padding-right:0.5em;"><a href="/wiki/Win%E2%80%93loss_record_(pitching)" title="Win–loss record (pitching)">Win–loss record</a></th>
# <td style="width:50%; padding-left:0.5em;">48–35</td>
# </tr>
# <tr>
# <th scope="row" style="text-align:right; width:50%; padding-right:0.5em;"><a href="/wiki/Earned_run_average" title="Earned run average">Earned run average</a></th>
# <td style="width:50%; padding-left:0.5em;">4.26</td>
# </tr>
# <tr>
# <th scope="row" style="text-align:right; width:50%; padding-right:0.5em;"><a href="/wiki/Strikeout" title="Strikeout">Strikeouts</a></th>
# <td style="width:50%; padding-left:0.5em;">446</td>
# </tr>
# <tr>
# <th scope="row" style="text-align:right; width:50%; padding-right:0.5em;"><a href="/wiki/Save_(baseball)" title="Save (baseball)">Saves</a></th>
# <td style="width:50%; padding-left:0.5em;">16</td>
# </tr>
# <tr style="background-color:#092C5C;color:#FFFFFF;">
# <th colspan="2" style="text-align:center">Teams</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center;text-align:left;">
# <ul>
# <li><a href="/wiki/Texas_Rangers_(baseball)" title="Texas Rangers (baseball)">Texas Rangers</a> (<a href="/wiki/2008_Major_League_Baseball_season" title="2008 Major League Baseball season">2008</a>–<a href="/wiki/2011_Major_League_Baseball_season" title="2011 Major League Baseball season">2011</a>)</li>
# <li><a href="/wiki/Baltimore_Orioles" title="Baltimore Orioles">Baltimore Orioles</a> (<a href="/wiki/2011_Major_League_Baseball_season" title="2011 Major League Baseball season">2011</a>–<a href="/wiki/2015_Major_League_Baseball_season" title="2015 Major League Baseball season">2015</a>)</li>
# <li><a href="/wiki/Chicago_Cubs" title="Chicago Cubs">Chicago Cubs</a> (<a href="/wiki/2015_Major_League_Baseball_season" title="2015 Major League Baseball season">2015</a>)</li>
# <li><a href="/wiki/Cleveland_Indians" title="Cleveland Indians">Cleveland Indians</a> (<a href="/wiki/2016_Major_League_Baseball_season" title="2016 Major League Baseball season">2016</a>)</li>
# <li><a href="/wiki/Baltimore_Orioles" title="Baltimore Orioles">Baltimore Orioles</a> (<a href="/wiki/2016_Major_League_Baseball_season" title="2016 Major League Baseball season">2016</a>)</li>
# </ul>
# </td>
# </tr>
# </table>
# <table class="infobox" style="width: 22em;">
# <tr>
# <th colspan="3" style="text-align:center; background-color:#b0c4de">Medal record</th>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;">Men's <a href="/wiki/Baseball" title="Baseball">baseball</a></th>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;" class="adr">Representing <span class="country-name"><span class="flagicon"><img alt="" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650" />&#160;</span><a href="/wiki/United_States" title="United States">United States</a></span></th>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#cccccc;"><a href="/wiki/World_University_Baseball_Championship" title="World University Baseball Championship">World University Championship</a></th>
# </tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;"><img alt="Gold medal – first place" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/16px-Gold_medal_icon_%28G_initial%29.svg.png" title="Gold medal – first place" width="16" height="16" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/24px-Gold_medal_icon_%28G_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/32px-Gold_medal_icon_%28G_initial%29.svg.png 2x" data-file-width="16" data-file-height="16" /></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/World_University_Baseball_Championship" title="World University Baseball Championship">2006 Havana</a></span></td>
# <td style="text-align:center;vertical-align:middle;"><a href="/wiki/United_States_national_baseball_team" title="United States national baseball team">National team</a></td>
# </tr>
# </table>
# <p><b>Raymond Thomas "Tommy" Hunter</b> (born July 3, 1986) is an American professional <a href="/wiki/Baseball" title="Baseball">baseball</a> <a href="/wiki/Pitcher" title="Pitcher">pitcher</a> who plays for the <a href="/wiki/Tampa_Bay_Rays" title="Tampa Bay Rays">Tampa Bay Rays</a> of <a href="/wiki/Major_League_Baseball" title="Major League Baseball">Major League Baseball</a> (MLB). He has played for the <a href="/wiki/Texas_Rangers_(baseball)" title="Texas Rangers (baseball)">Texas Rangers</a>, <a href="/wiki/Chicago_Cubs" title="Chicago Cubs">Chicago Cubs</a>, <a href="/wiki/Cleveland_Indians" title="Cleveland Indians">Cleveland Indians</a> and <a href="/wiki/Baltimore_Orioles" title="Baltimore Orioles">Baltimore Orioles</a>.</p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Amateur_career"><span class="tocnumber">1</span> <span class="toctext">Amateur career</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Major_league_career"><span class="tocnumber">2</span> <span class="toctext">Major league career</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#Texas_Rangers"><span class="tocnumber">2.1</span> <span class="toctext">Texas Rangers</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Baltimore_Orioles"><span class="tocnumber">2.2</span> <span class="toctext">Baltimore Orioles</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Chicago_Cubs"><span class="tocnumber">2.3</span> <span class="toctext">Chicago Cubs</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Cleveland_Indians"><span class="tocnumber">2.4</span> <span class="toctext">Cleveland Indians</span></a></li>
# <li class="toclevel-2 tocsection-7"><a href="#Second_stint_with_the_Baltimore_Orioles"><span class="tocnumber">2.5</span> <span class="toctext">Second stint with the Baltimore Orioles</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-8"><a href="#References"><span class="tocnumber">3</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-9"><a href="#External_links"><span class="tocnumber">4</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="Amateur_career">Amateur career</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=1" title="Edit section: Amateur career">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Born and raised in <a href="/wiki/Indianapolis" title="Indianapolis">Indianapolis</a>, <a href="/wiki/Indiana" title="Indiana">Indiana</a>, Hunter attended <a href="/wiki/Cathedral_High_School_(Indianapolis)" title="Cathedral High School (Indianapolis)">Cathedral High School</a>,<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">[1]</a></sup> and then the <a href="/wiki/University_of_Alabama" title="University of Alabama">University of Alabama</a>. At Alabama, Hunter played for the <a href="/wiki/Alabama_Crimson_Tide_baseball" title="Alabama Crimson Tide baseball">Alabama Crimson Tide</a> and was an <a href="/wiki/All-American" class="mw-redirect" title="All-American">All-American</a> in his freshman season, during which the team won the 2006 <a href="/wiki/Southeastern_Conference" title="Southeastern Conference">Southeastern Conference</a> Championship.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">[2]</a></sup></p>
# <h2><span class="mw-headline" id="Major_league_career">Major league career</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=2" title="Edit section: Major league career">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="Texas_Rangers">Texas Rangers</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=3" title="Edit section: Texas Rangers">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="thumb tleft">
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Tommy_Hunter.JPG" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/70/Tommy_Hunter.JPG/220px-Tommy_Hunter.JPG" width="220" height="244" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/70/Tommy_Hunter.JPG/330px-Tommy_Hunter.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/70/Tommy_Hunter.JPG/440px-Tommy_Hunter.JPG 2x" data-file-width="1704" data-file-height="1890" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Tommy_Hunter.JPG" class="internal" title="Enlarge"></a></div>
# Hunter with Texas Rangers</div>
# </div>
# </div>
# <p>Hunter was drafted by the <a href="/wiki/Texas_Rangers_(baseball)" title="Texas Rangers (baseball)">Texas Rangers</a> in the supplemental first round of the <a href="/wiki/2007_Major_League_Baseball_Draft" class="mw-redirect" title="2007 Major League Baseball Draft">2007 Major League Baseball Draft</a> out of the <a href="/wiki/University_of_Alabama" title="University of Alabama">University of Alabama</a>. The Rangers were awarded a compensatory pick when <a href="/wiki/Mark_DeRosa" title="Mark DeRosa">Mark DeRosa</a> left to go to the <a href="/wiki/Chicago_Cubs" title="Chicago Cubs">Chicago Cubs</a> in <a href="/wiki/Free_agent" title="Free agent">free agency</a>.</p>
# <p>Hunter made his major league debut on August 1, 2008, taking on the <a href="/wiki/Toronto_Blue_Jays" title="Toronto Blue Jays">Toronto Blue Jays</a>. In 5 innings, he gave up 6 <a href="/wiki/Run_(baseball)" title="Run (baseball)">runs</a> on 8 <a href="/wiki/Hit_(baseball)" title="Hit (baseball)">hits</a>, <a href="/wiki/Base_on_balls" title="Base on balls">walking</a> two and <a href="/wiki/Strikeout" title="Strikeout">striking out</a> four batters. He recorded his first MLB win on July 3, 2009 against the <a href="/wiki/Tampa_Bay_Rays" title="Tampa Bay Rays">Tampa Bay Rays</a>, going 5.1 innings of 1 run 5 K ball. He recorded his first Major League complete game on September 13, 2009 against the <a href="/wiki/Seattle_Mariners" title="Seattle Mariners">Seattle Mariners</a>. On October 3, 2009 Hunter gave up <a href="/wiki/Ken_Griffey_Jr" class="mw-redirect" title="Ken Griffey Jr">Ken Griffey Jr</a>'s 630th career <a href="/wiki/Home_run" title="Home run">home run</a>.</p>
# <p>Hunter made his 2010 season debut on June 5, pitching a complete game win against the <a href="/wiki/Tampa_Bay_Rays" title="Tampa Bay Rays">Tampa Bay Rays</a>. He was 13–4 for the season, with a 3.73 ERA. Hunter started Game 4 of the ALCS vs the <a href="/wiki/New_York_Yankees" title="New York Yankees">Yankees</a>.</p>
# <h3><span class="mw-headline" id="Baltimore_Orioles">Baltimore Orioles</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=4" title="Edit section: Baltimore Orioles">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>On July 30, 2011, the Rangers traded Hunter and <a href="/wiki/First_baseman" title="First baseman">first baseman</a> <a href="/wiki/Chris_Davis_(baseball)" title="Chris Davis (baseball)">Chris Davis</a> to the <a href="/wiki/Baltimore_Orioles" title="Baltimore Orioles">Baltimore Orioles</a> for reliever <a href="/wiki/Koji_Uehara" title="Koji Uehara">Koji Uehara</a>.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">[3]</a></sup> In the 2012 season, Hunter posted a 7–8 record. He was a starter for a while, but was optioned to Triple A Norfolk. He was placed in the bullpen as a reliever. As a reliever Hunter's fastball averaged 96 MPH over the month of September, and topped out at 100 MPH, after averaging 91-92 MPH for his career.<sup id="cite_ref-4" class="reference"><a href="#cite_note-4">[4]</a></sup></p>
# <p>After former closer <a href="/wiki/Jim_Johnson_(baseball,_born_1983)" title="Jim Johnson (baseball, born 1983)">Jim Johnson</a> was traded to the <a href="/wiki/Oakland_Athletics" title="Oakland Athletics">Oakland Athletics</a>, Hunter was named the new Orioles closer for the 2014 season.</p>
# <p>Hunter did start the 2014 season as the Orioles closer and was successful in 11 of his 12 save opportunities, but he blew 2 consecutive saves on May 10 and 13 and then was placed on the 15-day disabled list.<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">[5]</a></sup> When he returned, he continued to work out of the bullpen, but not as the closer. He agreed to a one year deal worth $4.65 million in January 2015, avoiding arbitration.<sup id="cite_ref-6" class="reference"><a href="#cite_note-6">[6]</a></sup></p>
# <h3><span class="mw-headline" id="Chicago_Cubs">Chicago Cubs</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=5" title="Edit section: Chicago Cubs">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>On July 31, 2015, Hunter was traded to the <a href="/wiki/Chicago_Cubs" title="Chicago Cubs">Chicago Cubs</a> for outfielder <a href="/wiki/Junior_Lake_(baseball)" class="mw-redirect" title="Junior Lake (baseball)">Junior Lake</a>.<sup id="cite_ref-7" class="reference"><a href="#cite_note-7">[7]</a></sup><sup id="cite_ref-8" class="reference"><a href="#cite_note-8">[8]</a></sup></p>
# <h3><span class="mw-headline" id="Cleveland_Indians">Cleveland Indians</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=6" title="Edit section: Cleveland Indians">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Hunter signed a one-year contract worth $2 million with the <a href="/wiki/Cleveland_Indians" title="Cleveland Indians">Cleveland Indians</a> on February 12, 2016.<sup id="cite_ref-9" class="reference"><a href="#cite_note-9">[9]</a></sup> He was placed on the disabled list on July 17 after suffering a non-displaced fracture in his back following a fall at his home.<sup id="cite_ref-10" class="reference"><a href="#cite_note-10">[10]</a></sup> On August 25, Hunter was released.<sup id="cite_ref-11" class="reference"><a href="#cite_note-11">[11]</a></sup></p>
# <h3><span class="mw-headline" id="Second_stint_with_the_Baltimore_Orioles">Second stint with the Baltimore Orioles</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=7" title="Edit section: Second stint with the Baltimore Orioles">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>The <a href="/wiki/Baltimore_Orioles" title="Baltimore Orioles">Baltimore Orioles</a> signed Hunter on August 28, 2016.<sup id="cite_ref-12" class="reference"><a href="#cite_note-12">[12]</a></sup></p>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=8" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist columns references-column-width" style="-moz-column-width: 30em; -webkit-column-width: 30em; column-width: 30em; list-style-type: decimal;">
# <ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.indystar.com/story/sports/baseball/2014/03/18/cathedral-alum-tommy-hunter-settling-into-baltimore-orioles-closer-role/6559061/">"Cathedral alum Tommy Hunter settling into Orioles' closer role"</a>. <i>Indianapolis Star</i>. March 18, 2014<span class="reference-accessdate">. Retrieved <span class="nowrap">April 6,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Cathedral+alum+Tommy+Hunter+settling+into+Orioles%27+closer+role&amp;rft.date=2014-03-18&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.indystar.com%2Fstory%2Fsports%2Fbaseball%2F2014%2F03%2F18%2Fcathedral-alum-tommy-hunter-settling-into-baltimore-orioles-closer-role%2F6559061%2F&amp;rft.jtitle=Indianapolis+Star&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.al.com/sports/index.ssf/2015/07/former_alabama_star_tommy_hunt.html">"MLB Trade Deadline 2015: Former Alabama star Tommy Hunter changes wild-card races in trade"</a>. <i>AL.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">February 13,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=MLB+Trade+Deadline+2015%3A+Former+Alabama+star+Tommy+Hunter+changes+wild-card+races+in+trade&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.al.com%2Fsports%2Findex.ssf%2F2015%2F07%2Fformer_alabama_star_tommy_hunt.html&amp;rft.jtitle=AL.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://hardballtalk.nbcsports.com/2011/07/30/report-orioles-close-to-trading-koji-uehara-to-rangers-for-chris-davis/">"Rangers to acquire Koji Uehara from Orioles for Chris Davis and Tommy Hunter"</a>. <i>HardballTalk</i><span class="reference-accessdate">. Retrieved <span class="nowrap">February 13,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Rangers+to+acquire+Koji+Uehara+from+Orioles+for+Chris+Davis+and+Tommy+Hunter&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fhardballtalk.nbcsports.com%2F2011%2F07%2F30%2Freport-orioles-close-to-trading-koji-uehara-to-rangers-for-chris-davis%2F&amp;rft.jtitle=HardballTalk&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.fangraphs.com/blogs/index.php/tommy-hunter-or-generics-versus-the-brand-name/">"Tommy Hunter, or Generics versus the Brand Name - FanGraphs Baseball"</a><span class="reference-accessdate">. Retrieved <span class="nowrap">February 13,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.btitle=Tommy+Hunter%2C+or+Generics+versus+the+Brand+Name+-+FanGraphs+Baseball&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.fangraphs.com%2Fblogs%2Findex.php%2Ftommy-hunter-or-generics-versus-the-brand-name%2F&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-5"><span class="mw-cite-backlink"><b><a href="#cite_ref-5">^</a></b></span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="http://espn.go.com/mlb/story/_/id/11052064/baltimore-orioles-activate-tommy-hunter-15-day-disabled-list?ex_cid=espnapi_public">"Tommy Hunter"</a>. ESPN.com<span class="reference-accessdate">. Retrieved <span class="nowrap">September 17,</span> 2014</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Tommy+Hunter&amp;rft.genre=article&amp;rft_id=http%3A%2F%2Fespn.go.com%2Fmlb%2Fstory%2F_%2Fid%2F11052064%2Fbaltimore-orioles-activate-tommy-hunter-15-day-disabled-list%3Fex_cid%3Despnapi_public&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-6"><span class="mw-cite-backlink"><b><a href="#cite_ref-6">^</a></b></span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="http://sports.espn.go.com/espn/wire?section=mlb&amp;id=12156949">"Orioles, Hunter agree on 1-year contract"</a>. ESPN.com. Associated Press. January 12, 2015<span class="reference-accessdate">. Retrieved <span class="nowrap">January 13,</span> 2015</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Orioles%2C+Hunter+agree+on+1-year+contract&amp;rft.date=2015-01-12&amp;rft.genre=article&amp;rft_id=http%3A%2F%2Fsports.espn.go.com%2Fespn%2Fwire%3Fsection%3Dmlb%26id%3D12156949&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-7"><span class="mw-cite-backlink"><b><a href="#cite_ref-7">^</a></b></span> <span class="reference-text"><cite class="citation web">Muskat, Carrie (July 31, 2015). <a rel="nofollow" class="external text" href="http://m.cubs.mlb.com/news/article/140132628">"Cubs get Hunter from O's, send Lake in return"</a>. <i>MLB.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">July 31,</span> 2015</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Cubs+get+Hunter+from+O%27s%2C+send+Lake+in+return&amp;rft.aufirst=Carrie&amp;rft.aulast=Muskat&amp;rft.date=2015-07-31&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fm.cubs.mlb.com%2Fnews%2Farticle%2F140132628&amp;rft.jtitle=MLB.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-8"><span class="mw-cite-backlink"><b><a href="#cite_ref-8">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="https://twitter.com/Orioles/status/627214664175353856">"Baltimore Orioles on Twitter"</a>. <i>Twitter</i><span class="reference-accessdate">. Retrieved <span class="nowrap">February 13,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Baltimore+Orioles+on+Twitter&amp;rft.genre=unknown&amp;rft_id=https%3A%2F%2Ftwitter.com%2FOrioles%2Fstatus%2F627214664175353856&amp;rft.jtitle=Twitter&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-9"><span class="mw-cite-backlink"><b><a href="#cite_ref-9">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.cleveland.com/tribe/index.ssf/2016/02/cleveland_indians_sign_rhp_tom.html">"Cleveland Indians sign RHP Tommy Hunter to 1-year deal worth $2 million"</a>. <i>cleveland.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">February 13,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Cleveland+Indians+sign+RHP+Tommy+Hunter+to+1-year+deal+worth+%242+million&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.cleveland.com%2Ftribe%2Findex.ssf%2F2016%2F02%2Fcleveland_indians_sign_rhp_tom.html&amp;rft.jtitle=cleveland.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-10"><span class="mw-cite-backlink"><b><a href="#cite_ref-10">^</a></b></span> <span class="reference-text"><cite class="citation web">Hoynes, Paul (July 17, 2016). <a rel="nofollow" class="external text" href="http://www.cleveland.com/tribe/index.ssf/2016/07/cleveland_indians_recall_cody_1.html#incart_river_index">"Cleveland Indians recall Cody Anderson; Tommy Hunter placed on disabled list"</a>. <i>cleveland.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">August 25,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Cleveland+Indians+recall+Cody+Anderson%3B+Tommy+Hunter+placed+on+disabled+list&amp;rft.aufirst=Paul&amp;rft.aulast=Hoynes&amp;rft.date=2016-07-17&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.cleveland.com%2Ftribe%2Findex.ssf%2F2016%2F07%2Fcleveland_indians_recall_cody_1.html%23incart_river_index&amp;rft.jtitle=cleveland.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-11"><span class="mw-cite-backlink"><b><a href="#cite_ref-11">^</a></b></span> <span class="reference-text"><cite class="citation news">Bastian, Jordan (August 25, 2016). <a rel="nofollow" class="external text" href="http://m.indians.mlb.com/news/article/197644728/veteran-rhp-tommy-hunter-released-by-indians/">"Veteran pitcher Hunter released by Tribe"</a>. MLB.com<span class="reference-accessdate">. Retrieved <span class="nowrap">August 29,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Veteran+pitcher+Hunter+released+by+Tribe&amp;rft.aufirst=Jordan&amp;rft.aulast=Bastian&amp;rft.date=2016-08-25&amp;rft.genre=article&amp;rft_id=http%3A%2F%2Fm.indians.mlb.com%2Fnews%2Farticle%2F197644728%2Fveteran-rhp-tommy-hunter-released-by-indians%2F&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-12"><span class="mw-cite-backlink"><b><a href="#cite_ref-12">^</a></b></span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="http://www.espn.com/mlb/story/_/id/17409282/baltimore-orioles-sign-rhp-tommy-hunter">"Orioles sign RHP Tommy Hunter"</a>. ESPN.com. Associated Press. August 28, 2016<span class="reference-accessdate">. Retrieved <span class="nowrap">August 29,</span> 2016</span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3ATommy+Hunter+%28baseball%29&amp;rft.atitle=Orioles+sign+RHP+Tommy+Hunter&amp;rft.date=2016-08-28&amp;rft.genre=article&amp;rft_id=http%3A%2F%2Fwww.espn.com%2Fmlb%2Fstory%2F_%2Fid%2F17409282%2Fbaltimore-orioles-sign-rhp-tommy-hunter&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# </ol>
# </div>
# <h2><span class="mw-headline" id="External_links">External links</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit&amp;section=9" title="Edit section: External links">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div role="navigation" aria-label="Portals" class="noprint portal plainlist tright" style="margin:0.5em 0 0.5em 1em;border:solid #aaa 1px">
# <ul style="display:table;box-sizing:border-box;padding:0.1em;max-width:175px;background:#f9f9f9;font-size:85%;line-height:110%;font-style:italic;font-weight:bold">
# <li style="display:table-row"><span style="display:table-cell;padding:0.2em;vertical-align:middle;text-align:center"><a href="/wiki/File:Baseball_(crop).jpg" class="image"><img alt="icon" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1e/Baseball_%28crop%29.jpg/29px-Baseball_%28crop%29.jpg" width="29" height="28" class="noviewer" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1e/Baseball_%28crop%29.jpg/43px-Baseball_%28crop%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1e/Baseball_%28crop%29.jpg/58px-Baseball_%28crop%29.jpg 2x" data-file-width="1697" data-file-height="1644" /></a></span><span style="display:table-cell;padding:0.2em 0.2em 0.2em 0.3em;vertical-align:middle"><a href="/wiki/Portal:Baseball" title="Portal:Baseball">Baseball portal</a></span></li>
# </ul>
# </div>
# <ul>
# <li>Career statistics and player information from <a rel="nofollow" class="external text" href="http://mlb.mlb.com/team/player.jsp?player_id=488984">MLB</a>, or&#160;<a rel="nofollow" class="external text" href="http://www.espn.com/mlb/player/stats/_/id/29198">ESPN</a>, or&#160;<a rel="nofollow" class="external text" href="http://www.baseball-reference.com/players/h/hunteto02.shtml">Baseball-Reference</a>, or&#160;<a rel="nofollow" class="external text" href="http://www.fangraphs.com/statss.aspx?playerid=1157">Fangraphs</a>, or&#160;<a rel="nofollow" class="external text" href="http://www.thebaseballcube.com/profile.asp?P=Tommy-Hunter-3">The Baseball Cube</a>, or&#160;<a rel="nofollow" class="external text" href="http://www.baseball-reference.com/minors/player.cgi?id=hunter001tom">Baseball-Reference (Minors)</a></li>
# </ul>
# <div role="navigation" class="navbox" aria-labelledby="2007_Major_League_Baseball_Draft_First_Round_Selections" style="padding:3px">
# <table class="nowraplinks collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# <tr>
# <th scope="col" class="navbox-title" colspan="2">
# <div class="plainlinks hlist navbar mini">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:2007_MLB_Draft" title="Template:2007 MLB Draft"><abbr title="View this template" style=";;background:none transparent;border:none;">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:2007_MLB_Draft" title="Template talk:2007 MLB Draft"><abbr title="Discuss this template" style=";;background:none transparent;border:none;">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:2007_MLB_Draft&amp;action=edit"><abbr title="Edit this template" style=";;background:none transparent;border:none;">e</abbr></a></li>
# </ul>
# </div>
# <div id="2007_Major_League_Baseball_Draft_First_Round_Selections" style="font-size:114%"><a href="/wiki/2007_Major_League_Baseball_draft" title="2007 Major League Baseball draft">2007 Major League Baseball Draft First Round Selections</a></div>
# </th>
# </tr>
# <tr style="height:2px">
# <td colspan="2"></td>
# </tr>
# <tr>
# <td colspan="2" class="navbox-list navbox-odd hlist" style="width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><a href="/wiki/David_Price_(baseball)" title="David Price (baseball)">David&#160;Price</a></li>
# <li><a href="/wiki/Mike_Moustakas" title="Mike Moustakas">Mike&#160;Moustakas</a></li>
# <li><a href="/wiki/Josh_Vitters" title="Josh Vitters">Josh&#160;Vitters</a></li>
# <li><a href="/wiki/Daniel_Moskos" title="Daniel Moskos">Daniel&#160;Moskos</a></li>
# <li><a href="/wiki/Matt_Wieters" title="Matt Wieters">Matt&#160;Wieters</a></li>
# <li><a href="/wiki/Ross_Detwiler" title="Ross Detwiler">Ross&#160;Detwiler</a></li>
# <li><a href="/wiki/Matt_LaPorta" title="Matt LaPorta">Matt&#160;LaPorta</a></li>
# <li><a href="/wiki/Casey_Weathers" title="Casey Weathers">Casey&#160;Weathers</a></li>
# <li><a href="/wiki/Jarrod_Parker" title="Jarrod Parker">Jarrod&#160;Parker</a></li>
# <li><a href="/wiki/Madison_Bumgarner" title="Madison Bumgarner">Madison&#160;Bumgarner</a></li>
# <li><a href="/wiki/Phillippe_Aumont" title="Phillippe Aumont">Phillippe&#160;Aumont</a></li>
# <li><a href="/wiki/Matt_Dominguez_(baseball)" title="Matt Dominguez (baseball)">Matt&#160;Dominguez</a></li>
# <li><a href="/wiki/Beau_Mills" title="Beau Mills">Beau&#160;Mills</a></li>
# <li><a href="/wiki/Jason_Heyward" title="Jason Heyward">Jason&#160;Heyward</a></li>
# <li><a href="/wiki/Devin_Mesoraco" title="Devin Mesoraco">Devin&#160;Mesoraco</a></li>
# <li><a href="/wiki/Kevin_Ahrens" title="Kevin Ahrens">Kevin&#160;Ahrens</a></li>
# <li><a href="/wiki/Blake_Beavan" title="Blake Beavan">Blake&#160;Beavan</a></li>
# <li><a href="/wiki/Pete_Kozma" title="Pete Kozma">Pete&#160;Kozma</a></li>
# <li><a href="/wiki/Joe_Savery" title="Joe Savery">Joe&#160;Savery</a></li>
# <li><a href="/wiki/Chris_Withrow" title="Chris Withrow">Chris&#160;Withrow</a></li>
# <li><a href="/wiki/J._P._Arencibia" title="J. P. Arencibia">J.&#160;P.&#160;Arencibia</a></li>
# <li>Tim&#160;Alderson</li>
# <li><a href="/wiki/Nick_Schmidt" title="Nick Schmidt">Nick&#160;Schmidt</a></li>
# <li>Michael&#160;Main</li>
# <li><a href="/wiki/Aaron_Poreda" title="Aaron Poreda">Aaron&#160;Poreda</a></li>
# <li>James&#160;Simmons</li>
# <li><a href="/wiki/Rick_Porcello" title="Rick Porcello">Rick&#160;Porcello</a></li>
# <li><a href="/wiki/Ben_Revere" title="Ben Revere">Ben&#160;Revere</a></li>
# <li>Wendell&#160;Fairley</li>
# <li><a href="/wiki/Andrew_Brackman" title="Andrew Brackman">Andrew&#160;Brackman</a></li>
# <li><a href="/wiki/Josh_Smoker" title="Josh Smoker">Josh&#160;Smoker</a></li>
# <li><a href="/wiki/Nick_Noonan" title="Nick Noonan">Nick&#160;Noonan</a></li>
# <li>Jon&#160;Gilmore</li>
# <li><a href="/wiki/Todd_Frazier" title="Todd Frazier">Todd&#160;Frazier</a></li>
# <li><a href="/wiki/Julio_Borbon" class="mw-redirect" title="Julio Borbon">Julio&#160;Borbon</a></li>
# <li><a href="/wiki/Clayton_Mortensen" title="Clayton Mortensen">Clayton&#160;Mortensen</a></li>
# <li><a href="/wiki/Travis_d%27Arnaud" title="Travis d'Arnaud">Travis&#160;d'Arnaud</a></li>
# <li><a href="/wiki/Brett_Cecil" title="Brett Cecil">Brett&#160;Cecil</a></li>
# <li><a href="/wiki/James_Adkins_(baseball)" class="mw-redirect" title="James Adkins (baseball)">James&#160;Adkins</a></li>
# <li><a href="/wiki/Kellen_Kulbacki" title="Kellen Kulbacki">Kellen&#160;Kulbacki</a></li>
# <li><a href="/wiki/Sean_Doolittle" title="Sean Doolittle">Sean&#160;Doolittle</a></li>
# <li><a href="/wiki/Eddie_Kunz" title="Eddie Kunz">Eddie&#160;Kunz</a></li>
# <li><a href="/wiki/Jackson_Williams" title="Jackson Williams">Jackson&#160;Williams</a></li>
# <li><a href="/wiki/Neil_Ramirez" title="Neil Ramirez">Neil&#160;Ramirez</a></li>
# <li>Justin&#160;Jackson</li>
# <li><a href="/wiki/Drew_Cumberland" title="Drew Cumberland">Drew&#160;Cumberland</a></li>
# <li>Nathan&#160;Vineyard</li>
# <li><a href="/wiki/Josh_Donaldson" title="Josh Donaldson">Josh&#160;Donaldson</a></li>
# <li>Michael&#160;Burgess</li>
# <li><a href="/wiki/Wes_Roemer" title="Wes Roemer">Wes&#160;Roemer</a></li>
# <li><a href="/wiki/Charlie_Culberson" title="Charlie Culberson">Charlie&#160;Culberson</a></li>
# <li><a href="/wiki/Matt_Mangini" title="Matt Mangini">Matt&#160;Mangini</a></li>
# <li><a href="/wiki/Kyle_Lotzkar" title="Kyle Lotzkar">Kyle&#160;Lotzkar</a></li>
# <li><strong class="selflink">Tommy&#160;Hunter</strong></li>
# <li><a href="/wiki/Nick_Hagadone" title="Nick Hagadone">Nick&#160;Hagadone</a></li>
# <li><a href="/wiki/Trystan_Magnuson" title="Trystan Magnuson">Trystan&#160;Magnuson</a></li>
# <li><a href="/wiki/Mitch_Canham" title="Mitch Canham">Mitch&#160;Canham</a></li>
# <li>Jonathan&#160;Bachanov</li>
# <li><a href="/wiki/Corey_Brown_(baseball)" title="Corey Brown (baseball)">Corey&#160;Brown</a></li>
# <li>Brandon&#160;Hamilton</li>
# <li><a href="/wiki/Ed_Easley" title="Ed Easley">Ed&#160;Easley</a></li>
# <li>Ryan&#160;Dent</li>
# <li><a href="/wiki/Cory_Luebke" title="Cory Luebke">Cory&#160;Luebke</a></li>
# <li>Danny&#160;Payne</li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <div role="navigation" class="navbox" aria-labelledby="Texas_Rangers_first-round_draft_picks" style="padding:3px">
# <table class="nowraplinks collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# <tr>
# <th scope="col" class="navbox-title" colspan="2" style="background-color:#003278;color:#FFFFFF;; border:#C0111F 2px solid">
# <div class="plainlinks hlist navbar mini">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:Texas_Rangers_first-round_draft_picks" title="Template:Texas Rangers first-round draft picks"><abbr title="View this template" style=";background-color:#003278;color:#FFFFFF;; border:#C0111F 2px solid;background:none transparent;border:none;">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:Texas_Rangers_first-round_draft_picks" title="Template talk:Texas Rangers first-round draft picks"><abbr title="Discuss this template" style=";background-color:#003278;color:#FFFFFF;; border:#C0111F 2px solid;background:none transparent;border:none;">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:Texas_Rangers_first-round_draft_picks&amp;action=edit"><abbr title="Edit this template" style=";background-color:#003278;color:#FFFFFF;; border:#C0111F 2px solid;background:none transparent;border:none;">e</abbr></a></li>
# </ul>
# </div>
# ...
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Tommy+Hunter+%28baseball%29" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Tommy+Hunter+%28baseball%29" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Tommy_Hunter_(baseball)"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Tommy_Hunter_(baseball)"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Tommy_Hunter_(baseball)" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Tommy_Hunter_(baseball)" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Tommy_Hunter_(baseball)" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;oldid=768192910" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q861479" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Tommy_Hunter_%28baseball%29&amp;id=768192910" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Tommy+Hunter+%28baseball%29">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Tommy+Hunter+%28baseball%29&amp;returnto=Tommy+Hunter+%28baseball%29&amp;oldid=768192910&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Tommy_Hunter_(baseball)&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-wikibase-otherprojects' aria-labelledby='p-wikibase-otherprojects-label'>
# 			<h3 id='p-wikibase-otherprojects-label'>In other projects</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="wb-otherproject-link wb-otherproject-commons"><a href="https://commons.wikimedia.org/wiki/Category:Tommy_Hunter" hreflang="en">Wikimedia Commons</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-fr"><a href="https://fr.wikipedia.org/wiki/Tommy_Hunter" title="Tommy Hunter – French" lang="fr" hreflang="fr" class="interlanguage-link-target">Français</a></li><li class="interlanguage-link interwiki-ko"><a href="https://ko.wikipedia.org/wiki/%ED%86%A0%EB%AF%B8_%ED%97%8C%ED%84%B0" title="토미 헌터 – Korean" lang="ko" hreflang="ko" class="interlanguage-link-target">한국어</a></li><li class="interlanguage-link interwiki-it"><a href="https://it.wikipedia.org/wiki/Tommy_Hunter" title="Tommy Hunter – Italian" lang="it" hreflang="it" class="interlanguage-link-target">Italiano</a></li><li class="interlanguage-link interwiki-ja"><a href="https://ja.wikipedia.org/wiki/%E3%83%88%E3%83%9F%E3%83%BC%E3%83%BB%E3%83%8F%E3%83%B3%E3%82%BF%E3%83%BC" title="トミー・ハンター – Japanese" lang="ja" hreflang="ja" class="interlanguage-link-target">日本語</a></li>					</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q861479#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 2 March 2017, at 10:29.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Tommy_Hunter_(baseball)&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.476","walltime":"0.564","ppvisitednodes":{"value":2213,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":71646,"limit":2097152},"templateargumentsize":{"value":4085,"limit":2097152},"expansiondepth":{"value":17,"limit":40},"expensivefunctioncount":{"value":1,"limit":500},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  480.601      1 -total"," 56.41%  271.109      3 Template:Infobox"," 34.80%  167.235      1 Template:Infobox_baseball_biography"," 29.60%  142.275      1 Template:Reflist"," 16.40%   78.806      7 Template:Cite_web"," 10.67%   51.261      2 Template:Baseball_navbox","  8.79%   42.269     11 Template:Infobox_baseball_biography/style","  6.13%   29.465      1 Template:Texas_Rangers_first-round_draft_picks","  6.12%   29.425      1 Template:Use_mdy_dates","  5.51%   26.472      1 Template:2007_MLB_Draft"]},"scribunto":{"limitreport-timeusage":{"value":"0.225","limit":"10.000"},"limitreport-memusage":{"value":3928272,"limit":52428800}},"cachereport":{"origin":"mw1208","timestamp":"20170302102933","ttl":3600,"transientcontent":true}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":55,"wgHostname":"mw1255"});});</script>
# 	</body>
# </html>

# %% [markdown]
# It looks like we can see this as a typical html page, even though it may look a bit cryptic to the unfamiliar reader. It appears that the main content is nested inside the div tag with the id content.

# %% [markdown]
# ## Reading in the Data
# Now that we know the file structure, and the structure of a single file, we can read in all of the files. This will get us started in our explorations.
#
# As this task is I/O bound, we can use threads to help us read in the data more quickly.
#
# Note: It may make sense to benchmark the performance with multiple threads versus single threaded performance.

# %%
# get some neccessary modules for threading and timing
import concurrent.futures
import time

# create a pool of 4 workers (arbitrary to user machine)
pool = concurrent.futures.ThreadPoolExecutor(max_workers=4)

# make function to read file to avoid redundancy
def read_data(filename):
    with open(filename) as f:
        data = f.read()
    return data

# time the start, read in files, and make into a content list
start = time.time()
filenames = ["wiki/{}".format(f) for f in os.listdir("wiki")]
content = pool.map(read_data, filenames)
content = list(content)

# time the end, see the difference (seconds) and convert to article name
end = time.time()
print(end - start)
articles = [f.replace(".html", "").replace("wiki/", "") for f in filenames]
# Out:
# 0.39919543266296387

# %% [markdown]
# Note that the time printed above will vary obviously due to variance.
#
# However, after doing some profiling, it doesn't appear that threading makes a huge difference to performance. It may be because although files are opened, most of the task is offset by the overhead of creating new threads.

# %% [markdown]
# ## Remove Extraneous Markup
# Now that we've read in the data files, we can remove the extraneous markup that's outside the div#content tag that most of the content seems to be inside (example):
#
#
# <script>...</script>
#         ...
#
#
#         ...
#         <div id="content">
#             ...
#         </div>
#         ...
#
#
# We can use the BeautifulSoup package for this. BeautifulSoup enables us to extract all of the content inside a specific tag. For more information on beautiful soup, look for the Reddit API project in the Data Analysis Github repo, else here is some documentation: https://www.crummy.com/software/BeautifulSoup/.
#
# Using the BeautifulSoup package, we'll parse each wiki article, then extract the div with id content and everything inside it.
#
# Since this operation is more CPU intensive than before, let's try using a process pool to see if the speed improves.

# %%
# get BS from bs4 edition
from bs4 import BeautifulSoup

# create function that reads in html, parses, extracts content div to string
def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return str(soup.find_all("div", id="content")[0])

# time ths start, create pool with 3 workers (arbitrary), parse content to list
start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
parsed = pool.map(parse_html, content)
parsed = list(parsed)

# time the end and see the difference (this will be quite long - over half a min)
end = time.time()
print(end - start)
# Out:
# 41.40981125831604

# %%
# let's look at some content
parsed[0]
# Out:
# '<div class="mw-body" id="content" role="main">\n<a id="top"></a>\n<div id="siteNotice"><!-- CentralNotice --></div>\n<div class="mw-indicators">\n</div>\n<h1 class="firstHeading" id="firstHeading" lang="en">Furubira District, Hokkaido</h1>\n<div class="mw-body-content" id="bodyContent">\n<div id="siteSub">From Wikipedia, the free encyclopedia</div>\n<div id="contentSub"></div>\n<div class="mw-jump" id="jump-to-nav">\n\t\t\t\t\tJump to:\t\t\t\t\t<a href="#mw-head">navigation</a>, \t\t\t\t\t<a href="#p-search">search</a>\n</div>\n<div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><table class="plainlinks metadata ambox ambox-content ambox-Unreferenced" role="presentation">\n<tr>\n<td class="mbox-image">\n<div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div>\n</td>\n<td class="mbox-text"><span class="mbox-text-span">This article <b>does not <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">cite</a> any <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">sources</a></b>. <span class="hide-when-compact">Please help <a class="external text" href="//en.wikipedia.org/w/index.php?title=Furubira_District,_Hokkaido&amp;action=edit">improve this article</a> by <a href="/wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1" title="Help:Introduction to referencing with Wiki Markup/1">adding citations to reliable sources</a>. Unsourced material may be challenged and <a href="/wiki/Wikipedia:Verifiability#Burden_of_evidence" title="Wikipedia:Verifiability">removed</a>.</span> <small><i>(December 2009)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>\n</tr>\n</table>\n<div class="thumb tright">\n<div class="thumbinner" style="width:202px;"><a class="image" href="/wiki/File:Furubira_in_Shiribeshi_Subprefecture.gif"><img alt="" class="thumbimage" data-file-height="368" data-file-width="600" height="123" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/200px-Furubira_in_Shiribeshi_Subprefecture.gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/300px-Furubira_in_Shiribeshi_Subprefecture.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Furubira_in_Shiribeshi_Subprefecture.gif/400px-Furubira_in_Shiribeshi_Subprefecture.gif 2x" width="200"/></a>\n<div class="thumbcaption">\n<div class="magnify"><a class="internal" href="/wiki/File:Furubira_in_Shiribeshi_Subprefecture.gif" title="Enlarge"></a></div>\nFurubira in Shiribeshi Subprefecture.</div>\n</div>\n</div>\n<p><b>Furubira</b> <span style="font-weight: normal">(<span class="t_nihongo_kanji" lang="ja" xml:lang="ja">古平郡</span><span class="t_nihongo_comma" style="display:none">,</span> <i>Furubira-gun</i><sup class="t_nihongo_help noprint"><a href="/wiki/Help:Installing_Japanese_character_sets" title="Help:Installing Japanese character sets"><span class="t_nihongo_icon" style="color: #00e; font: bold 80% sans-serif; text-decoration: none; padding: 0 .1em;">?</span></a></sup>)</span> is a <a href="/wiki/Districts_of_Japan" title="Districts of Japan">district</a> located in <a href="/wiki/Shiribeshi_Subprefecture" title="Shiribeshi Subprefecture">Shiribeshi Subprefecture</a>, <a href="/wiki/Hokkaido" title="Hokkaido">Hokkaido</a>, <a href="/wiki/Japan" title="Japan">Japan</a>.</p>\n<p>As of 2004, the district has an es ...

# %% [markdown]
# It turns out that this operation is quite slow and CPU-intensive. It looks like using as many processes are there are available processors speeds things up.

# %% [markdown]
# ## Finding Common Tags
# Now that we've extracted the main part of each page, let's count up how many times each tag occurs. This will give us clues about how Wikipedia pages are typically structured. For example, if there are a lot of a tags on each page, we know that Wikipedia articles tend to be very connected to other articles or pages. On the other hand, a lot of div tags will tell us that Wikipedia pages tend to have a nested structure with many page elements.
#
# We can count tags using the BeautifulSoup.find_all() method with no argument, then iterating through all of the tags.

# %%
# create function to count tags - parse and use find_all to fill dict
def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        if tag.name not in tags:
            tags[tag.name] = 0
        tags[tag.name] += 1
    return tags

# time the start, make pool with 3 workers (arbitrary), map the function to list
start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
tags = pool.map(count_tags, parsed)
tags = list(tags)

# make tag_counts dict and double loop to count tags
tag_counts = {}
for tag in tags:
    for k,v in tag.items():
        if k not in tag_counts:
            tag_counts[k] = 0
        tag_counts[k] += v
        
# time the end and see the difference (intensive - about half a min)
end = time.time()
print(end - start)

# display tag counts
tag_counts
# Out:
# 20.382586240768433
# {'a': 161065,
#  'abbr': 3665,
#  'annotation': 2,
#  'area': 39,
#  'audio': 2,
#  'b': 14455,
#  'bdi': 4,
#  'big': 75,
#  'blockquote': 58,
#  'br': 4986,
#  'caption': 200,
#  'center': 64,
#  'cite': 3563,
#  'code': 108,
#  'dd': 1376,
#  'del': 2,
#  'div': 28581,
#  'dl': 457,
#  'dt': 334,
#  'font': 40,
#  'h1': 999,
#  'h2': 4045,
#  'h3': 777,
#  'h4': 117,
#  'h5': 4,
#  'h6': 1,
#  'hr': 51,
#  'i': 18246,
#  'img': 6701,
#  'li': 85779,
#  'map': 2,
#  'math': 2,
#  'mo': 2,
#  'mrow': 2,
#  'mstyle': 2,
#  'noscript': 999,
#  'ol': 858,
#  'p': 7998,
#  'pre': 1,
#  'q': 76,
#  'rb': 16,
#  'rp': 32,
#  'rt': 16,
#  'ruby': 16,
#  's': 10,
#  'samp': 2,
#  'semantics': 2,
#  'small': 3272,
#  'source': 2,
#  'span': 67350,
#  'strong': 599,
#  'sub': 151,
#  'sup': 11157,
#  'table': 4010,
#  'td': 57673,
#  'th': 14472,
#  'tr': 27300,
#  'u': 51,
#  'ul': 10972,
#  'wbr': 85}

# %% [markdown]
# Based on our findings, it looks like there are quite a few td, a, li, and span tags. This indicates that articles tend to have lots of links, along with lists and tables. Links are the most numerous tag, which indicates how interconnected articles on Wikipedia are. It is to be expected, which is usually a good thing in analysis! Confirmation works just as well as discovery.

# %% [markdown]
# ## Finding Common Words
# After finding the common tags, we should be able to find the common words in the article body. We can apply any definition of "word" that we want, but it might be helpful to apply a criteria of some sort. This process will be very similar to finding the common tags.
#
# **Note: One thing to be aware of here is that depending on the words you choose and depending on your user machine, you may run out of memory, or performance may be slow. Try tweaking things to improve performance if necessary.**

# %%
# get some counting module help
from collections import Counter
import re

# create function to count words - parse, get_text, clean and take words >5 len
def count_words(html):
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = re.sub("\W+", " ", text.lower())
    words = text.split(" ")
    words = [w for w in words if len(w) >= 5]
    return Counter(words).most_common(10)

# time the start, make pool of 3 workers (arbitrary), map count_words into list
start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=3)
words = pool.map(count_words, parsed)
words = list(words)

# make word_counts dict and double loop to count words
word_counts = {}
for wc in words:
    for word, count in wc:
        if word not in word_counts:
            word_counts[word] = 0
        word_counts[word] += 1
        
# time the end and show the difference - same as above - about half a min
end = time.time()
print(end - start)

# display word counts
word_counts
# Out:
# 21.52505874633789
# {'genus': 20,
#  'schleswig': 1,
#  'daughter': 5,
#  'frescoes': 1,
#  'appearance': 2,
#  'nadeshiko': 1,
#  'flanders': 1,
#  'medical': 6,
#  'tournaments': 1,
#  'clare': 1,
#  'ioana': 1,
#  'chicken': 1,
#  'heath': 1,
#  'march': 31,
#  'daveigh': 1,
#  'festival': 11,
#  'bijar': 1,
#  'trees': 1,
#  'elizabeth': 2,
#  'pradesh': 3,
#  'hardcore': 1,
#  'fuselage': 1,
#  'england': 14,
#  'independent': 3,
#  'faber': 2,
#  'gustavsson': 1,
#  'ontario': 2,
#  'growth': 3,
#  'pascal': 1,
#  'winds': 1,
#  'walking': 1,
#  'ministry': 3,
#  'honey': 1,
#  'gokhale': 1,
#  'champion': 1,
#  'diptera': 1,
#  'distortion': 1,
#  'items': 1,
#  'fischtown': 1,
#  'kattukukke': 1,
#  'editions': 1,
#  'suter': 1,
#  'panthers': 1,
#  'recke': 1,
#  'ingelheim': 1,
#  'triathlon': 1,
#  'suburbs': 1,
#  'georgia': 5,
#  'pless': 1,
#  'genes': 1,
#  'arena': 2,
#  'malta': 2,
#  'catalunya': 1,
#  'cárdenas': 1,
#  'artistic': 2,
#  'these': 4,
#  'liberal': 6,
#  'minardi': 1,
#  'atlantic': 3,
#  'logistic': 1,
#  'lavender': 1,
#  'vitalic': 1,
#  'kolbuszowa': 1,
#  'donje': 1,
#  'constitution': 1,
#  'medicine': 2,
#  'recommendations': 1,
#  'ratio': 1,
#  'shibanova': 1,
#  'piraí': 1,
#  'oates': 1,
#  'frisian': 1,
#  'canton': 1,
#  'riverside': 2,
#  'trilobite': 1,
#  'jeddo': 1,
#  'middle': 1,
#  'paris': 3,
#  'artist': 1,
#  'bonita': 1,
#  'choline': 1,
#  'kenya': 2,
#  'confronting': 1,
#  'without': 4,
#  'composers': 1,
#  'ankara': 1,
#  'homebuilding': 1,
#  'maukala': 1,
#  'pempheris': 1,
#  'kistenuten': 1,
#  'aprilia': 1,
#  'vivet': 1,
#  'hearing': 1,
#  'sítio': 1,
#  'friedlich': 1,
#  'tatar': 1,
#  'ōnogō': 1,
#  'lanka': 1,
#  'beetles': 1,
#  'waterfront': 1,
#  'studies': 2,
#  'sreekumaran': 2,
#  'maddrell': 1,
#  'abbeville': 1,
#  'insectivorous': 1,
#  'tyrosine': 1,
#  'flamengo': 1,
#  'writing': 3,
#  'stuttgart': 1,
#  'fools': 1,
#  'calderini': 1,
#  'culture': 1,
#  'pounder': 1,
#  'founded': 2,
#  'scored': 1,
#  'affiliated': 1,
#  'subfamily': 1,
#  'proprietary': 1,
#  'geological': 1,
#  'birkenhead': 1,
#  'serena': 1,
#  'mickey': 1,
#  'ultimate': 1,
#  'ghair': 1,
#  'derbi': 1,
#  'sheehan': 1,
#  'fluminense': 1,
#  'virus': 2,
#  'bytów': 1,
#  'malabsorption': 1,
#  'vishka': 1,
#  'belfast': 1,
#  'leone': 1,
#  'talmudic': 1,
#  'graah': 1,
#  'ralston': 1,
#  'palestine': 1,
#  'sudan': 1,
#  'killings': 1,
#  'margo': 1,
#  'kupres': 1,
#  'languages': 2,
#  'telescope': 1,
#  'damsa': 1,
#  'verse': 1,
#  'leandra': 1,
#  'pozoblanco': 1,
#  'visualization': 2,
#  'berkeley': 1,
#  'justus': 1,
#  'emotions': 1,
#  'scientist': 1,
#  'kurtzman': 1,
#  'woody': 1,
#  'uzbekistan': 1,
#  'chicks': 1,
#  'portal': 5,
#  'gundeck': 1,
#  'recipe': 1,
#  'christian': 1,
#  'mayor': 5,
#  'bahrain': 1,
#  'counsel': 1,
#  'forrest': 1,
#  'emily': 1,
#  'acyltransferase': 1,
#  'shekhar': 1,
#  'school': 38,
#  'docking': 1,
#  'light': 1,
#  'pinafore': 1,
#  'egypt': 1,
#  'miguel': 1,
#  'mayagüez': 1,
#  'kushiro': 1,
#  'seasons': 3,
#  'essay': 1,
#  '916846': 1,
#  'technology': 1,
#  'woodbine': 1,
#  'notozeucta': 1,
#  'weight': 1,
#  'врила': 1,
#  'every': 1,
#  'galaxy': 1,
#  'microsoft': 1,
#  'issue': 1,
#  'marie': 1,
#  'passing': 1,
#  'features': 1,
#  'functions': 1,
#  'ferdinand': 1,
#  'comanche': 1,
#  'zemmour': 1,
#  'bundela': 1,
#  'foulonia': 1,
#  'reveals': 1,
#  'angustata': 1,
#  'waldau': 1,
#  'expert': 1,
#  'green': 8,
#  'meleh': 1,
#  'newton': 2,
#  'plant': 7,
#  'label': 3,
#  'muslims': 1,
#  'measure': 1,
#  'série': 1,
#  'sauce': 1,
#  'students': 7,
#  'pinzón': 1,
#  'murex': 1,
#  'encyclopedia': 12,
#  'giesbert': 1,
#  'tygři': 1,
#  'niknahal': 1,
#  'corinth': 1,
#  'template': 8,
#  'figaro': 1,
#  'wirral': 1,
#  'defendant': 1,
#  'bolivia': 1,
#  '09194': 1,
#  'colombiana': 1,
#  'caves': 1,
#  'norwegian': 6,
#  'vitamin': 1,
#  'trusts': 1,
#  'sculptor': 1,
#  'stephen': 1,
#  'peptide': 2,
#  'singer': 3,
#  'carte': 1,
#  'goldau': 1,
#  'interacting': 1,
#  'awarded': 1,
#  'ascomycota': 1,
#  'horror': 2,
#  'silveira': 1,
#  'flute': 1,
#  'chart': 11,
#  'dialogue': 1,
#  'musicians': 1,
#  'deren': 1,
#  '64167': 1,
#  'asteraceae': 1,
#  'bureau': 1,
#  'arrowhead': 1,
#  'braunschweig': 1,
#  'homeboys': 1,
#  'diamond': 1,
#  'möschler': 1,
#  'kanakomyrtus': 1,
#  '7311611': 1,
#  'nuding': 1,
#  'bagrat': 1,
#  'article': 64,
#  'kusaka': 1,
#  'atienza': 1,
#  'cardiff': 1,
#  'kaisertal': 1,
#  'rebel': 1,
#  'holland': 1,
#  'guide': 2,
#  'ishikari': 1,
#  'réunion': 1,
#  'edelen': 1,
#  'boneh': 1,
#  'buffalo': 1,
#  'colleges': 1,
#  'higher': 1,
#  'calyptraeidae': 1,
#  'matthew': 2,
#  'message': 2,
#  'nations': 4,
#  'kross': 1,
#  'engineering': 7,
#  'kilkenny': 1,
#  'madero': 1,
#  'subsidiaries': 1,
#  'collinlab': 1,
#  'solanales': 1,
#  'melling': 1,
#  'runoff': 1,
#  'dream': 3,
#  'anchor': 1,
#  'orioles': 1,
#  'agonists': 2,
#  'defeating': 1,
#  'katie': 1,
#  'mixto': 1,
#  'biases': 1,
#  'zoomshops': 1,
#  'baronetage': 1,
#  'battle': 8,
#  'doumanaba': 1,
#  'military': 7,
#  'madrasa': 1,
#  'google': 5,
#  'scout': 1,
#  'peaks': 1,
#  'quartet': 1,
#  'chance': 1,
#  'playoffs': 2,
#  'footballersgermany': 1,
#  'citations': 8,
#  'block': 2,
#  'hastings': 1,
#  'malaysian': 1,
#  'novelist': 1,
#  'performance': 4,
#  'chromosome': 2,
#  'ogham': 1,
#  'keshav': 1,
#  'hours': 1,
#  'women': 22,
#  'taiwan': 2,
#  'division': 10,
#  'brighouse': 1,
#  'pablo': 1,
#  'indianapolis': 1,
#  'manuscript': 1,
#  'orscher': 1,
#  'biteback': 1,
#  'mosque': 2,
#  'clark': 3,
#  'workers': 1,
#  'network': 4,
#  'mykines': 1,
#  'niger': 1,
#  'massachusetts': 4,
#  'keller': 1,
#  'techniques': 1,
#  'puerto': 3,
#  'diego': 2,
#  'component': 1,
#  'yarkand': 1,
#  'range': 1,
#  'montana': 3,
#  'country': 9,
#  'fleet': 1,
#  'curtis': 1,
#  'aviation': 3,
#  'factor': 1,
#  'dorsal': 1,
#  'olive': 1,
#  'cruise': 1,
#  'freeman': 1,
#  'memorial': 2,
#  'erceg': 1,
#  'battles': 1,
#  'tainan': 1,
#  'brooder': 1,
#  'podcasting': 1,
#  'coalville': 1,
#  'spradlin': 1,
#  'transport': 2,
#  'scotland': 4,
#  'bafinivirus': 1,
#  'imperialis': 1,
#  'knowledge': 1,
#  'rolli': 1,
#  'boogie': 2,
#  'hapten': 1,
#  'strayhorn': 1,
#  'peltigera': 1,
#  'sacksioni': 1,
#  'yolks': 1,
#  'qualified': 1,
#  'davison': 1,
#  'rehman': 1,
#  'unverified': 1,
#  'mecklenburgische': 1,
#  'fruit': 1,
#  'banate': 1,
#  'fischli': 1,
#  'lecithocera': 1,
#  'pastor': 2,
#  'vanek': 1,
#  'league': 24,
#  'leskovac': 1,
#  '23833': 1,
#  'التخطيط': 1,
#  'charleston': 1,
#  'monsignor': 1,
#  'channels': 1,
#  'foodservice': 1,
#  'procés': 1,
#  'orthaea': 1,
#  'renault': 2,
#  'soldier': 2,
#  'jonesy': 1,
#  'dottermans': 1,
#  'dzikowiec': 1,
#  'personal': 1,
#  'colony': 2,
#  'genera': 1,
#  'berries': 1,
#  'otago': 1,
#  'dhayalan': 1,
#  'philpott': 1,
#  'republic': 11,
#  'early': 1,
#  'aleksandra': 1,
#  'bells': 1,
#  'industry': 1,
#  'virginia': 5,
#  'langer': 1,
#  'tolombeh': 1,
#  'gustav': 1,
#  'portrait': 1,
#  'french': 21,
#  'award': 6,
#  'serbian': 1,
#  'timothy': 1,
#  'yugoslavia': 1,
#  'safety': 1,
#  'swindon': 1,
#  'olivaceus': 1,
#  'guitar': 4,
#  'stadium': 3,
#  'berry': 1,
#  'seine': 1,
#  'spider': 2,
#  'phycita': 1,
#  'woman': 2,
#  'radio': 8,
#  'dayton': 1,
#  'mcadams': 1,
#  'osaka': 1,
#  'harris': 1,
#  'colliery': 1,
#  'diving': 1,
#  'shooting': 1,
#  'burrell': 1,
#  'paulo': 2,
#  'natasha': 1,
#  'roofs': 1,
#  'curridge': 1,
#  'entitled': 1,
#  'jotedar': 1,
#  'trojans': 1,
#  'latin': 5,
#  'director': 7,
#  'primitives': 1,
#  'building': 13,
#  'located': 4,
#  'dawson': 1,
#  'methyl': 1,
#  'lewis': 2,
#  'lovis': 1,
#  'variety': 1,
#  '92528': 1,
#  'mexican': 1,
#  'hemet': 1,
#  'political': 7,
#  'roberts': 1,
#  'education': 9,
#  'demography': 1,
#  'teshio': 1,
#  'brett': 1,
#  'construction': 4,
#  'novgorod': 1,
#  'inches': 1,
#  'vrila': 1,
#  '96917': 1,
#  'politician': 5,
#  'laoag': 1,
#  'nyblom': 1,
#  'democrat': 2,
#  'sprue': 1,
#  'sankaradi': 1,
#  'kosovo': 1,
#  'dextran': 1,
#  'sowme': 1,
#  'constable': 1,
#  'graham': 2,
#  'fighter': 1,
#  '45x90': 1,
#  'watsonville': 1,
#  'kannan': 1,
#  'processor': 1,
#  'malayalam': 2,
#  'eddie': 1,
#  'italian': 7,
#  'papyrus': 1,
#  'hurricanes': 1,
#  'william': 12,
#  'okinawa': 1,
#  'phước': 1,
#  'odisha': 1,
#  'surveillance': 1,
#  '61861': 1,
#  'rivals': 1,
#  'ciółkowo': 1,
#  'michelin': 1,
#  'entrance': 1,
#  'allmusic': 1,
#  'monroe': 1,
#  'strawberry': 1,
#  'lithuanian': 1,
#  'ismacryp': 1,
#  'wetangula': 1,
#  'modeling': 1,
#  'dosan': 2,
#  'britain': 2,
#  'infusella': 1,
#  'unique': 1,
#  'apelor': 1,
#  'casimcea': 1,
#  'holly': 1,
#  'honor': 1,
#  'chełmno': 1,
#  'gatineau': 1,
#  'inoue': 1,
#  'buday': 1,
#  'jaipur': 1,
#  'immune': 1,
#  'macroglossum': 1,
#  'guatemala': 1,
#  'gliese': 1,
#  'salle': 2,
#  'dipterologische': 1,
#  'ctenodes': 1,
#  'state': 29,
#  'microphthalmia': 1,
#  'transit': 1,
#  'forewings': 1,
#  'irihirose': 1,
#  'clive': 1,
#  'makushita': 1,
#  'airlines': 2,
#  'modern': 3,
#  'blocks': 1,
#  'divertimento': 1,
#  'points': 2,
#  'loving': 1,
#  'clarence': 1,
#  'gotland': 1,
#  'officer': 2,
#  'yarumal': 1,
#  'colombia': 3,
#  'spyware': 1,
#  'eggerberg': 1,
#  'steel': 2,
#  'falkland': 1,
#  'pastime': 1,
#  'baddie': 1,
#  'suite': 1,
#  'president': 6,
#  'murphy': 1,
#  'thalkirchen': 1,
#  'dualism': 1,
#  'kaloyan': 1,
#  'nabil': 1,
#  'wehrmacht': 1,
#  'dominica': 1,
#  'chenar': 1,
#  'grade': 1,
#  'published': 5,
#  'golabkhvaran': 1,
#  'lothian': 1,
#  'notable': 4,
#  'gamalyan': 1,
#  'aircraft': 5,
#  'partisan': 1,
#  'preapicemaculata': 1,
#  'gregory': 2,
#  'those': 2,
#  '6014889': 1,
#  'independiente': 1,
#  'vosta': 1,
#  'qirush': 1,
#  'lierne': 1,
#  'legend': 1,
#  '1880s': 1,
#  '152778': 1,
#  'support': 2,
#  'billy': 2,
#  'hungarian': 1,
#  'bethioua': 1,
#  'wordfence': 1,
#  'journalist': 1,
#  'batken': 1,
#  'cavite': 1,
#  'guadalajara': 2,
#  'which': 37,
#  'khulo': 1,
#  'liberty': 2,
#  'ixtlán': 1,
#  'sheath': 1,
#  'jstor': 1,
#  'groves': 1,
#  'weert': 1,
#  'thanks': 1,
#  'entrepreneur': 1,
#  'abdullah': 1,
#  'mbilinyi': 1,
#  'vikings': 1,
#  'povolný': 1,
#  'maccabees': 1,
#  'retail': 1,
#  'cesaris': 1,
#  'works': 4,
#  'conformation': 1,
#  'reaction': 1,
#  'mcclave': 1,
#  'family': 37,
#  'identifierswikipedia': 18,
#  'married': 3,
#  'romana': 1,
#  'elisa': 1,
#  'cheremshanka': 1,
#  'bivalvia': 1,
#  'ladanyi': 1,
#  'walla': 1,
#  'social': 11,
#  'semjan': 1,
#  'sunita': 1,
#  'jackson': 1,
#  'yetholm': 1,
#  'windsor': 1,
#  'thailand': 1,
#  'trade': 2,
#  'lively': 1,
#  'sands': 1,
#  'biological': 1,
#  'chiddingstone': 1,
#  'chickens': 1,
#  'virajpet': 1,
#  'noaimi': 1,
#  'jonstrup': 1,
#  'percentage': 1,
#  'rissoidae': 1,
#  'achaea': 1,
#  'princeton': 2,
#  'talcahuano': 1,
#  'council': 5,
#  'foster': 2,
#  'deciusalis': 1,
#  'pilestedt': 1,
#  'oklahoma': 4,
#  'forsberg': 1,
#  'functoids': 1,
#  'hewitt': 1,
#  'words': 1,
#  'cosmopterix': 1,
#  'wangerooge': 1,
#  'transfer': 1,
#  'teamtennis': 1,
#  'palestinian': 2,
#  'tofanellidae': 1,
#  'never': 1,
#  'politics': 3,
#  'windows': 1,
#  'songwriter': 1,
#  'kyokutou': 1,
#  'baltic': 1,
#  'salter': 1,
#  'senshusei': 1,
#  'anambra': 1,
#  'screenwriter': 1,
#  'nurayn': 1,
#  'succeeded': 2,
#  'farmeshkhan': 1,
#  'potheri': 1,
#  'person': 3,
#  'roxbury': 1,
#  'heroines': 1,
#  'peene': 1,
#  'jackets': 1,
#  'plasnewydd': 1,
#  'lawrence': 1,
#  'hester': 1,
#  'tortricidae': 3,
#  'transportation': 2,
#  'frosinone': 1,
#  'boone': 1,
#  'homebuilt': 1,
#  'sneakers': 1,
#  'collin': 1,
#  'composed': 1,
#  'varus': 1,
#  'exclusive': 1,
#  'kyril': 1,
#  'martini': 1,
#  'farvandsvæsenet': 1,
#  'armagh': 1,
#  'capped': 1,
#  'kendal': 1,
#  'tamil': 6,
#  'motorsport': 1,
#  'keisling': 1,
#  'arrondissements': 1,
#  'yuzhno': 1,
#  'bruses': 1,
#  'wronki': 1,
#  'guaricana': 1,
#  'erotic': 1,
#  'valley': 6,
#  'khaled': 1,
#  'clinic': 1,
#  'shibanov': 1,
#  'nalbant': 1,
#  'hockey': 11,
#  'obersendling': 1,
#  'école': 1,
#  'index': 6,
#  'sentences': 1,
#  'cercle': 1,
#  'length': 2,
#  'yards': 2,
#  'løwert': 1,
#  'national': 34,
#  'timiș': 1,
#  'cricket': 8,
#  'pacific': 3,
#  'thikana': 1,
#  'books': 3,
#  'rundata': 1,
#  'antibiotic': 1,
#  'camera': 1,
#  'sources': 21,
#  'sangro': 1,
#  'pentangle': 1,
#  'river': 16,
#  'marten': 1,
#  'association': 6,
#  'parco': 1,
#  'shanghai': 2,
#  'participations': 1,
#  'korea': 1,
#  'phorids': 1,
#  'minsk': 2,
#  'systems': 3,
#  'gottfried': 1,
#  'automobiles': 1,
#  'motorcycle': 2,
#  'greenhouses': 1,
#  'babar': 1,
#  'szczecin': 1,
#  'abanycha': 1,
#  'shioda': 1,
#  'helen': 2,
#  'discretionary': 1,
#  'reality': 2,
#  'planets': 1,
#  'buren': 1,
#  'bianchi': 1,
#  'coffee': 1,
#  'candidate': 2,
#  'stream': 1,
#  'kfarhata': 1,
#  'quebec': 1,
#  'gelechiidae': 1,
#  'finns': 1,
#  'braga': 1,
#  'brzózka': 1,
#  'shelters': 1,
#  'florabase': 1,
#  'sings': 1,
#  'yangmingshan': 1,
#  'agents': 1,
#  'truss': 1,
#  'image': 3,
#  'tommy': 1,
#  'reverse': 1,
#  '000000001989': 1,
#  'tephritidae': 1,
#  'purdy': 1,
#  'spence': 1,
#  'respiratory': 1,
#  'origin': 1,
#  'halle': 1,
#  'laniidae': 1,
#  'metallica': 2,
#  'estonia': 1,
#  'eating': 1,
#  'boutique': 1,
#  'vojin': 1,
#  'personalities': 1,
#  'kawczynski': 1,
#  'woods': 1,
#  'solydxk': 1,
#  'zonata': 1,
#  'banovinas': 1,
#  'meizu': 1,
#  'muller': 1,
#  '61306': 1,
#  'records': 11,
#  'streatfeilds': 1,
#  'ellington': 1,
#  'kazan': 1,
#  'scope': 1,
#  'kings': 1,
#  'untersuchungen': 1,
#  'maarten': 1,
#  'pérez': 1,
#  'hyojong': 1,
#  'amokwe': 1,
#  'letters': 1,
#  'champs': 1,
#  'sicily': 1,
#  'democratic': 3,
#  'shoals': 1,
#  'dakar': 1,
#  'générale': 1,
#  'karluks': 1,
#  'troops': 1,
#  'myrtaceae': 1,
#  'torpedo': 1,
#  'panhandle': 1,
#  'yoshinkan': 1,
#  'nicotinic': 1,
#  'syncretocarpus': 1,
#  'staff': 1,
#  'learn': 5,
#  'cancrivora': 1,
#  'elections': 8,
#  'wirrina': 1,
#  'indicated': 1,
#  'holbæk': 1,
#  'hierarchy': 1,
#  'noctuidae': 1,
#  'jordan': 3,
#  'bobruisk': 1,
#  'mammoth': 1,
#  'arthritis': 1,
#  'solomona': 1,
#  'belgian': 1,
#  'metropolitan': 1,
#  'hispanic': 1,
#  'istanbul': 1,
#  'bardhaman': 1,
#  'myrtle': 1,
#  'lincoln': 2,
#  'fuscozonata': 1,
#  'mussel': 1,
#  'krasnoyarsk': 1,
#  'programme': 1,
#  'totnes': 1,
#  'syndrome': 2,
#  'indigenous': 1,
#  'could': 2,
#  'kenny': 4,
#  'circuit': 1,
#  'andersson': 1,
#  'cardona': 1,
#  'flashmob': 1,
#  'heroes': 1,
#  'cruze': 1,
#  'armenian': 1,
#  'comedy': 4,
#  'missal': 1,
#  'tischofer': 1,
#  'beasley': 1,
#  'sanford': 1,
#  'kasaragod': 1,
#  'thompson': 1,
#  'establishments': 1,
#  'sibling': 1,
#  'constituencies': 1,
#  'jahad': 1,
#  'roland': 1,
#  'dartmouth': 1,
#  'maría': 3,
#  'pictogram': 1,
#  'player': 2,
#  'amborellaceae': 1,
#  'marion': 1,
#  'horseback': 1,
#  'mountune': 1,
#  'infected': 2,
#  'furious': 1,
#  'church': 18,
#  'slade': 1,
#  'limited': 5,
#  'facility': 1,
#  'botany': 1,
#  'bonny': 1,
#  'believe': 1,
#  '46667': 1,
#  'garza': 1,
#  'minnow': 1,
#  'molecular': 1,
#  'neighbourhood': 1,
#  'biscuit': 1,
#  'athletics': 7,
#  'roush': 1,
#  'access': 2,
#  'archdeacon': 1,
#  'taipei': 1,
#  'goran': 2,
#  'united': 58,
#  'aidala': 1,
#  'bullying': 1,
#  '78278': 1,
#  'stage': 6,
#  'leksikon': 1,
#  'release': 2,
#  'famous': 1,
#  'srrsh': 1,
#  'odder': 1,
#  'kildare': 1,
#  'velika': 1,
#  'maharaj': 1,
#  'withers': 1,
#  'became': 2,
#  'craters': 2,
#  'vostochny': 1,
#  'phosphatase': 1,
#  'liberec': 2,
#  'seats': 2,
#  'angiosperm': 1,
#  'laser': 1,
#  'aldrich': 1,
#  'place': 3,
#  'vries': 1,
#  'andhra': 1,
#  'fleabane': 1,
#  'rahmed': 1,
#  'gobeyr': 1,
#  'impact': 1,
#  'tungsten': 1,
#  'storm': 2,
#  'étaule': 1,
#  'portugal': 3,
#  'plains': 2,
#  'roster': 1,
#  'floor': 1,
#  'flemish': 1,
#  'garfield': 2,
#  'kavčič': 1,
#  'bogdanov': 1,
#  'vaccinium': 1,
#  'remix': 1,
#  'ghost': 1,
#  'telugu': 1,
#  'mullich': 1,
#  'guards': 1,
#  '89972': 1,
#  'porter': 2,
#  'defensive': 1,
#  'marine': 6,
#  'winnipeg': 1,
#  'asparuh': 1,
#  'career': 25,
#  'major': 2,
#  'devadiga': 1,
#  'ricky': 1,
#  'gašparci': 1,
#  'hertford': 1,
#  'ceramics': 1,
#  'benidorm': 1,
#  'urban': 3,
#  'appointed': 1,
#  'esporte': 1,
#  'fedcup': 1,
#  'external': 15,
#  'lecithoceridae': 1,
#  'alvarez': 1,
#  'mohammad': 2,
#  'antae': 1,
#  'steroid': 1,
#  'shown': 1,
#  'nathan': 1,
#  'sylvia': 1,
#  'darüşşafaka': 1,
#  'railroad': 1,
#  'heart': 1,
#  'jourdan': 1,
#  'tomislav': 1,
#  'nîmes': 1,
#  'kingston': 1,
#  'abbasabad': 1,
#  'lakes': 5,
#  'cobreloa': 1,
#  'burdine': 1,
#  'structure': 8,
#  'armor': 1,
#  'coaches': 1,
#  'keyboards': 1,
#  'charged': 1,
#  '89444': 1,
#  'gaetanus': 1,
#  'malavika': 1,
#  'cragin': 1,
#  'dorgali': 1,
#  'public': 5,
#  'comandante': 1,
#  'promises': 1,
#  'tlélat': 1,
#  'sometimes': 1,
#  'combat': 1,
#  'mountains': 1,
#  'vending': 1,
#  'bulgarian': 3,
#  'dušanovo': 1,
#  'pseudoluteata': 1,
#  'census': 15,
#  ...}

# %%
# example of just running the function - leads to a reference object display
words = pool.map(count_words, parsed)
words
# Out:
# <generator object result_iterator at 0x7f7ca0192d80>

# %% [markdown]
# From the code above, we see that only selecting the top 10 words from each article speeds up performance quite a bit.

# %% [markdown]
# ## Further Analysis / Next Steps
# Even though this was some pretty basic analysis on wiki articles, there are a few more things to explore that we can take note of. For complete analysis projects, take a look at especially the Reddit API project mentioned before in this writeup. The information is essentially the same, as this project focused a bit more on data engineering.

# %% [markdown]
# ## Analysis Questions
# With that being said, some topics to explore might be:
# * What tags have the most content inside of them?
# * What articles are most commonly linked to from our articles?
# * What phrases are the most common?
# * What's the distribution of letters per word? How many 3 letter words are there? 4 letter?
# * What's the average reading level of a Wikipedia article? Use readability metrics.
# * What images are most commonly shown in articles?
#
# Most of these questions can pretty much be answered with some time using the above functions and looking into the htmls, and this is more of a guide to process your own questions for things that you yourself may find interesting.
#
# For example, it is pretty easy to find the most content tags; just filter by len. And also pretty easy to find the distribution of letters; literally just replace the 5 in the word function with 3, 4, etc. However, if you were interested in using this distribution to then see what topics of articles these distributions catered to the most - this could be useful. All analyses build on each other, it never really stops. Again, it just pertains to the individual's interest most of the time.

# %% [markdown]
# ## Conclusion
# Most problems in data engineering are also fundamentally scale problems. The more data you have, the harder it is to process, and the more tradeoffs you have to make. It would be useful to download more articles, so that scale becomes more of a problem. Can you work with 1 gigabyte of articles, and have a reasonably fast processing methods? How about 10 gigabytes? This project did not involve that for two reasons:
# * Downloading 10 GB of data for an example project is a bit overkill.
# * With more data, there is more tradeoff, but ultimately more redundancy as well. While you may have to optimize here and there, the code generally stays the same format.
#
# All in all, this project was a good basis on data engineering combined with some simple analysis tools such as threading and using beautiful soup. Threading can be very useful when working with big companies on big projects, but to be honest, most of the time you won't even need it.
#
# It all comes down to experience and knowing when to use something is just as important as knowing when not to use something. Threading and data engineering, when used right, can exponentially make data analysis more powerful!
